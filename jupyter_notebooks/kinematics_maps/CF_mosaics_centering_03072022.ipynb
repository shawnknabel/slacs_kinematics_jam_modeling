# %% [markdown]
# # 3/7/2022 - This notebook locates the center of each of CF mosaics so that the cutout for kinematics is centered correctly.

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from ppxf.kcwi_util import register_sauron_colormap
from ppxf.kcwi_util import visualization
from ppxf.kcwi_util import get_datacube
from ppxf.kcwi_util import ppxf_kinematics_RXJ1131_getGlobal_lens_deredshift
from ppxf.kcwi_util import find_nearest
from ppxf.kcwi_util import SN_CaHK
from ppxf.kcwi_util import select_region
from ppxf.kcwi_util import voronoi_binning
from ppxf.kcwi_util import get_voronoi_binning_data
from ppxf.kcwi_util import get_velocity_dispersion_deredshift
from ppxf.kcwi_util import kinematics_map
from ppxf.kcwi_util import stellar_type

register_sauron_colormap()

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ0029-0055'
obj_abbr = obj_name[4:9] # e.g. J0029


'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 60, 129
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
#------------------------------------------------------------------------------

# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ0037-0942'
obj_abbr = obj_name[4:9] # e.g. J0029
z = 0.195 # lens redshift
T_exp = 1800*3*60 #266 * 60

'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"

'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 59, 137 #130
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ0330-0020'
obj_abbr = obj_name[4:9] # e.g. J0029
z = 0.351 # lens redshift
T_exp = 1800*6*60 #266 * 60

'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"

'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 59, 133
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ1306+0600'
obj_abbr = obj_name[4:9] # e.g. J0029
z = 0.173 # lens redshift
T_exp = 1800*3*60 + 1500*60 #266 * 60

'''
Step 0: input the necessary information of the datacube
'''

    
#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"

'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 56, 137
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ1531-0105'
obj_abbr = obj_name[4:9] # e.g. J0029
z = 0.16 # lens redshift
T_exp = 1200*4*60 + 80*60 #266 * 60

'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 33, 102
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ1621+3931'
obj_abbr = obj_name[4:9] # e.g. J0029


'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 30, 99
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ1627-0053'
obj_abbr = obj_name[4:9] # e.g. J0029


'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 56, 134
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ1630+4520'
obj_abbr = obj_name[4:9] # e.g. J0029


'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 59, 131
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)

# %%
# Set 'obj_name', 'z', 'T_exp'
obj_name = 'SDSSJ2303+1422'
obj_abbr = obj_name[4:9] # e.g. J0029


'''
Step 0: input the necessary information of the datacube
'''

#data directorysingle sudo linux
dir = f'/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/CF_mosaics/{obj_name}/' # wait what is this drizzle file?

	#		"/Volumes/Seagate/drizzlepac_test/drizzle_file_KCWI_J1630/"

#KCWI mosaic datacube
name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'
			#"KCWI_J1630_icubes_mosaic_0.1457"



'''
Step 1: visualization of the KCWI mosaic datacube
'''
# visualize the entire mosaic data
hdu = fits.open(dir + name + ".fits")
visualization(hdu)

# cute the datacube centered at 56, 133
lens_center_x,lens_center_y = 58, 124
radius_in_pixels = 21
data_crop = get_datacube(hdu, lens_center_x, lens_center_y, radius_in_pixels)
