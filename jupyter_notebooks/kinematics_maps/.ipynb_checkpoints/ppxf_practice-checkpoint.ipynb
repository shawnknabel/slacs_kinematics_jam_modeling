# %% [markdown]
# # 2/22/22 - Working with pPXF Sauron example to get familiar with package.

# %%
#!/usr/bin/env python
##############################################################################
#
# Usage example for the procedure PPXF, which implements the
# Penalized Pixel-Fitting (pPXF) method originally described in
# Cappellari M., & Emsellem E., 2004, PASP, 116, 138
#     http://adsabs.harvard.edu/abs/2004PASP..116..138C
# and upgraded in Cappellari M., 2017, MNRAS, 466, 798
#     http://adsabs.harvard.edu/abs/2017MNRAS.466..798C
#
# The example also shows how to include a library of templates
# and how to mask gas emission lines if present.
#
# MODIFICATION HISTORY:
#   V1.0.0: Written by Michele Cappellari, Leiden 11 November 2003
#   V1.1.0: Log rebin the galaxy spectrum. Show how to correct the velocity
#       for the difference in starting wavelength of galaxy and templates.
#       MC, Vicenza, 28 December 2004
#   V1.1.1: Included explanation of correction for instrumental resolution.
#       After feedback from David Valls-Gabaud. MC, Venezia, 27 June 2005
#   V2.0.0: Included example routine to determine the goodPixels vector
#       by masking known gas emission lines. MC, Oxford, 30 October 2008
#   V2.0.1: Included instructions for high-redshift usage. Thanks to Paul Westoby
#       for useful feedback on this issue. MC, Oxford, 27 November 2008
#   V2.0.2: Included example for obtaining the best-fitting redshift.
#       MC, Oxford, 14 April 2009
#   V2.1.0: Bug fix: Force PSF_GAUSSIAN to produce a Gaussian with an odd
#       number of elements centered on the middle one. Many thanks to
#       Harald Kuntschner, Eric Emsellem, Anne-pMarie Weijmans and
#       Richard McDermid for reporting problems with small offsets
#       in systemic velocity. MC, Oxford, 15 February 2010
#   V2.1.1: Added normalization of galaxy spectrum to avoid numerical
#       instabilities. After feedback from Andrea Cardullo.
#       MC, Oxford, 17 March 2010
#   V2.2.0: Perform templates convolution in linear wavelength.
#       This is useful for spectra with large wavelength range.
#       MC, Oxford, 25 March 2010
#   V2.2.1: Updated for Coyote Graphics. MC, Oxford, 11 October 2011
#   V2.2.2: Renamed PPXF_KINEMATICS_EXAMPLE_SAURON to avoid conflict with the
#       new PPXF_KINEMATICS_EXAMPLE_SDSS. Removed DETERMINE_GOOPIXELS which was
#       made a separate routine. MC, Oxford, 12 January 2012
#   V3.0.0: Translated from IDL into Python. MC, Oxford, 6 December 2013
#   V3.0.1: Support both Python 2.6/2.7 and Python 3.x. MC, Oxford, 25 May 2014
#   V3.0.2: Explicitly sort template files as glob() output may not be sorted.
#       Thanks to Marina Trevisan for reporting problems under Linux.
#       MC, Sydney, 4 February 2015
#   V3.0.3: Use redshift in determine_goodpixels. MC, Oxford, 5 May 2015
#   V3.0.4: Support both Pyfits and Astropy to read FITS files.
#       MC, Oxford, 22 October 2015
#   V3.1.0: Replaced the Vazdekis-99 SSP models with the Vazdekis+10 ones.
#       MC, Oxford, 3 May 2016
#   V3.1.1: Illustrate how to use a higher sampling for the template, via the
#       `velscale_ratio` keyword. MC, Oxford, 22 June 2016
#   V3.1.2: Use proper input `vsyst` when `velscale_ratio` > 1.
#       Thanks to Kyle Westfall for finding this issue in the MaNGA DAP.
#       MC, Oxford, 19 October 2016
#   V3.1.3: Make files paths relative to this file, to run the example from
#       any directory. MC, Oxford, 18 January 2017
#   V3.1.4: Updated text on the de-redshifting of the spectrum.
#       MC, Oxford, 5 October 2017
#   V3.1.5: Changed imports for pPXF as a package.
#       Make file paths relative to the pPXF package to be able to run the
#       example unchanged from any directory. MC, Oxford, 17 April 2018
#   V3.1.6: Dropped legacy Python 2.7 support. MC, Oxford, 10 May 2018
#   V3.1.7: Fixed clock DeprecationWarning in Python 3.7.
#       MC, Oxford, 27 September 2018
#
##############################################################################

import glob
from os import path
from time import perf_counter as clock

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

def ppxf_example_kinematics_sauron():

    ppxf_dir = path.dirname(path.realpath(ppxf_package.__file__))

    # Read a galaxy spectrum and define the wavelength range
    #
    file = ppxf_dir + '/spectra/NGC4550_SAURON.fits'
    hdu = fits.open(file)
    gal_lin = hdu[0].data
    h1 = hdu[0].header
    
    print(h1.keys)
    

    lamRange1 = h1['CRVAL1'] + np.array([0., h1['CDELT1']*(h1['NAXIS1'] - 1)])
    FWHM_gal = 4.2  # SAURON has an instrumental resolution FWHM of 4.2A.

    # If the galaxy is at significant redshift, one should bring the galaxy
    # spectrum roughly to the rest-frame wavelength, before calling pPXF
    # (See Sec.2.4 of Cappellari 2017). In practice there is no
    # need to modify the spectrum in any way, given that a red shift
    # corresponds to a linear shift of the log-rebinned spectrum.
    # One just needs to compute the wavelength range in the rest-frame
    # and adjust the instrumental resolution of the galaxy observations.
    # This is done with the following three commented lines:
    #
    # z = 1.23 # Initial estimate of the galaxy redshift
    # lamRange1 = lamRange1/(1+z) # Compute approximate restframe wavelength range
    # FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom

    galaxy, logLam1, velscale = util.log_rebin(lamRange1, gal_lin)
    galaxy = galaxy/np.median(galaxy)  # Normalize spectrum to avoid numerical issues
    noise = np.full_like(galaxy, 0.0047)           # Assume constant noise per pixel here

    # Read the list of filenames from the Single Stellar Population library
    # by Vazdekis (2010, MNRAS, 404, 1639) http://miles.iac.es/. A subset
    # of the library is included for this example with permission
    vazdekis = glob.glob(ppxf_dir + '/miles_models/Mun1.30*.fits')
    FWHM_tem = 2.51  # Vazdekis+10 spectra have a constant resolution FWHM of 2.51A.
    velscale_ratio = 2  # adopts 2x higher spectral sampling for templates than for galaxy

    # Extract the wavelength range and logarithmically rebin one spectrum
    # to a velocity scale 2x smaller than the SAURON galaxy spectrum, to determine
    # the size needed for the array which will contain the template spectra.
    #
    hdu = fits.open(vazdekis[0])
    ssp = hdu[0].data
    h2 = hdu[0].header
    lamRange2 = h2['CRVAL1'] + np.array([0., h2['CDELT1']*(h2['NAXIS1'] - 1)])
    sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
    templates = np.empty((sspNew.size, len(vazdekis)))

    # Convolve the whole Vazdekis library of spectral templates
    # with the quadratic difference between the SAURON and the
    # Vazdekis instrumental resolution. Logarithmically rebin
    # and store each template as a column in the array TEMPLATES.

    # Quadratic sigma difference in pixels Vazdekis --> SAURON
    # The formula below is rigorously valid if the shapes of the
    # instrumental spectral profiles are well approximated by Gaussians.
    #
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/h2['CDELT1']  # Sigma difference in pixels   # 2.355*sigma is the fwhm

    for j, file in enumerate(vazdekis):
        hdu = fits.open(file)
        ssp = hdu[0].data
        ssp = ndimage.gaussian_filter1d(ssp, sigma)
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates[:, j] = sspNew/np.median(sspNew)  # Normalizes templates

    # The galaxy and the template spectra do not have the same starting wavelength.
    # For this reason an extra velocity shift DV has to be applied to the template
    # to fit the galaxy spectrum. We remove this artificial shift by using the
    # keyword VSYST in the call to PPXF below, so that all velocities are
    # measured with respect to DV. This assume the redshift is negligible.
    # In the case of a high-redshift galaxy one should de-redshift its
    # wavelength to the rest frame before using the line below (see above).
    #
    c = 299792.458
    dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c  # km/s

    z = 0.0015  # Initial redshift estimate of the galaxy
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)

    # Here the actual fit starts. The best fit is plotted on the screen.
    # Gas emission lines are excluded from the pPXF fit using the GOODPIXELS keyword.
    #
    vel = c*np.log(1 + z)   # eq.(8) of Cappellari (2017)
    start = [vel, 200.]  # (km/s), starting guess for [V, sigma]
    t = clock()

    pp = ppxf(templates, galaxy, noise, velscale, start,
              goodpixels=goodPixels, plot=True, moments=4,
              degree=4, vsyst=dv, velscale_ratio=velscale_ratio)

    print("Formal errors:")
    print("     dV    dsigma   dh3      dh4")
    print("".join("%8.2g" % f for f in pp.error*np.sqrt(pp.chi2)))

    print('Elapsed time in pPXF: %.2f s' % (clock() - t))

    # If the galaxy is at significant redshift z and the wavelength has been
    # de-redshifted with the three lines "z = 1.23..." near the beginning of
    # this procedure, the best-fitting redshift is now given by the following
    # commented line (equation 2 of Cappellari et al. 2009, ApJ, 704, L34;
    # http://adsabs.harvard.edu/abs/2009ApJ...704L..34C)
    #
    # print('Best-fitting redshift z:', (z + 1)*(1 + pp.sol[0]/c) - 1)

#------------------------------------------------------------------------------

if __name__ == '__main__':

    ppxf_example_kinematics_sauron()
    import matplotlib.pyplot as plt
    plt.pause(1)
# Out:
# <bound method Header.keys of SIMPLE  =                    T / Written by IDL:  Wed Dec 29 00:44:01 2004
# BITPIX  =                  -32 / Number of bits per data pixel
# NAXIS   =                    1 / Number of data axes
# NAXIS1  =                  415 /
# DATE    = '2004-12-28'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# CRVAL1  =        4824.60000000 /
# CDELT1  =        1.10000000000 /                                                >
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       436       113     0.032     0.066
# chi2/DOF: 1.015; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  9 / 150
# Formal errors:
#      dV    dsigma   dh3      dh4
#      2.4     5.2   0.018   0.032
# Elapsed time in pPXF: 0.79 s

# %% [markdown]
# ____________________________
#
# # Let's try it on one of the datacubes.

# %%
import glob
from os import path
from time import perf_counter as clock

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

# %%
# take in galaxy spectra and identify the pieces I need

#ppxf_dir = path.dirname(path.realpath(ppxf_package.__file__))
kin_dir = '/local/shawnknabel/slacs_kinematics/'

# Read a galaxy spectrum and define the wavelength range
#
file = f'{kin_dir}KCWI_J0029_icubes_mosaic_0.1457.fits' #ppxf_dir + '/spectra/NGC4550_SAURON.fits'
hdu = fits.open(file)
galaxy_cube = hdu[0].data
h1 = hdu[0].header

#print(h1.keys)
# Out:
# <bound method Header.keys of SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  119
# NAXIS2  =                  256
# NAXIS3  =                 5215
# EXTEND  =                    T
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2021-08-13T13:14:42' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# COMMENT BEGIN detector-server-specific keywords
# OFNAME  = 'kb210813_00039.fits' / original file name
# DATEPCLR= '2021-08-13T12:41:52.538' / most recent erase
# DATE-BEG= '2021-08-13T12:41:52.538' / exposure begin
# DATE-END= '2021-08-13T13:11:52.557' / exposure end
# DATEREND= '2021-08-13T13:14:41.907' / readout end
# XPOSURE =                1800. / [s] shutter open duration
# TELAPSE =             1800.019 / [s] dark current duration
# TTIME   =                1800. / [s] target exposure time
# NUMOPEN =                    1 / number of shutter opens
# NUMCLOS =                    1 / number of shutter closes
# NSHFUP  =                    0 / number of shuffle ups
# NSHFDN  =                    0 / number of shuffle downs
# CCDCFG  = '1101009 '           / CCD Config: XYSGGAA
# BINNING = '1,1     '           / binning: serial/axis1, parallel/axis2
# AMPMODE = 'TUP     '           / name of detector readout mode
# AMPMNUM =                    9 / number of detector readout mode
# NVIDINP =                    2 / number of active video inputs
# INTGAIN =                 1.67 / intrinsic gain (e-/DN)
# GAINMUL =                   10 / gain multiplier (1,2,5,10)
# CCDGAIN =                0.167 / gain (e-/DN)
# NAMPSXY = '2 1     '           / active video inputs along axis1 axis2
# COMMENT For the definitions of the IRAF section keywords refer to
# COMMENT http://iraf.noao.edu/projects/ccdmosaic/imagedef/imagedef.html
# CCDSUM  = '1 1     '           / IRAF ccdsum
# AMPNAME1= 'H       '           / amp name, readout sequence 0
# AMPID1  =                    2 / amp Id number, readout sequence 0
# GAIN1   =                0.163 / gain (e-/DN) for amp 0
# AMPNAME2= 'G       '           / amp name, readout sequence 1
# AMPID2  =                    3 / amp Id number, readout sequence 1
# GAIN2   =                0.161 / gain (e-/DN) for amp 1
# COMMENT END detector-server-specific keywords
# COMMENT ------------------------------------------------------------------------
# COMMENT keyheader version 96230
# COMMENT Location: /kroot/rel/default/bin/keyheader
# COMMENT Configuration: /kroot/rel/default/data/kcwi/keyheader.conf
# COMMENT Hostname: kcwitarg
# COMMENT Program start time: 2021-08-13T13:14:42.324749Z
# COMMENT ------------------------------------------------------------------------
# COMMENT
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT keyheader section [ExposureBegin]
# COMMENT Snapshot timestamp: 2021-08-13T12:41:52.538000Z
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT
# COMMENT The following records correspond to the beginning of the exposure,
# COMMENT as recorded in the DATE-BEG record.
# AUTOSHUT=                    1 / automatic shutter operation
# IDLECLOK=                    1 / idle clocking
# SHUFROWS=                 1370 / [ccdrows] number of rows in shuffle
# PPRECLR =                    1 / parallel pre-clear (erase)
# CCDMODE =                    0 / CCD speed mode (slow-0/fast-1)
# CCDSPEED=                    0 / CCD readout speed
# INTSPEED=                    0 / CCD integrator speed
# OBJECT  = '0029-0055'          / Object name
# OBSERVER= 'Bennert,Chen,Williams' / Observer name
# INSTRUME= 'KCWI    '           / Instrument
# CAMERA  = 'BLUE    '           / Camera (blue,red,fpc)
# IMTYPE  = 'OBJECT  '           / Image type
# GROUPID = '2021-08-13-39'      / Group ID
# COMMENT No further records from the beginning of the exposure.
# COMMENT
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT keyheader section [heartbeats]
# COMMENT Snapshot timestamp: 2021-08-13T12:41:52.538000Z
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT
# HEART_01= 'Heartbeat active'   / kbds.UPTIME
# HEART_02= 'Heartbeat active'   / kbes.UPTIME
# HEART_03= 'Heartbeat active'   / kbgs.UPTIME
# HEART_04= 'Heartbeat active'   / kbms.UPTIME
# HEART_05= 'Heartbeat active'   / kbvs.UPTIME
# HEART_06= 'Heartbeat active'   / kcas.UPTIME
# HEART_07= 'Heartbeat active'   / kcwi.GSUPTIME
# HEART_08= 'Heartbeat active'   / kp1s.UPTIME
# HEART_09= 'Heartbeat active'   / kp2s.UPTIME
# HEART_10= 'Heartbeat active'   / kp3s.UPTIME
# HEART_11= 'Heartbeat active'   / kt1s.UPTIME
# HEART_12= 'Heartbeat active'   / kt2s.UPTIME
# COMMENT
# COMMENT ------------------------------------------------------------------------
# COMMENT End of keyheader output
# COMMENT Program start time: 2021-08-13T13:14:42.324749Z
# COMMENT Program end time:   2021-08-13T13:14:42.539168Z
# COMMENT ------------------------------------------------------------------------
# COMMENT ------------------------------------------------------------------------
# COMMENT keyheader version 96230
# COMMENT Location: /kroot/rel/default/bin/keyheader
# COMMENT Configuration: /kroot/rel/default/data/kcwi/keyheader.conf
# COMMENT Hostname: kcwitarg
# COMMENT Program start time: 2021-08-13T13:14:42.909966Z
# COMMENT ------------------------------------------------------------------------
# COMMENT
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT keyheader section [ExposureEnd]
# COMMENT Snapshot timestamp: 2021-08-13T13:11:52.557000Z
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT
# COMMENT The following records correspond to the end of the exposure,
# COMMENT as recorded in the DATE-END record.
# CURRINST= 'KCWI    '           / DCS Instrument
# TARGNAME= 'SDSSJ0029-0055'     / DCS Target name
# PONAME  = 'IFU     '           / DCS Point origin name
# RA      = '00:29:07.75'        / DCS RA
# DEC     = '-00:55:55.5'        / DCS Dec
# TARGRA  = '00:29:07.78'        / DCS Target RA
# TARGDEC = '-00:55:50.5'        / DCS Target Dec
# EQUINOX =               2000.0 / DCS Equinox
# DRA     =                  0.0 / DCS Diff RA rate (s/s)
# DDEC    =                  0.0 / DCS Diff Dec rate (asec/s)
# RABASE  = '00:29:07.78'        / DCS RA base
# RAOFF   =                 -0.5 / DCS RA offset (asec)
# DECBASE = '-00:55:54.5'        / DCS Dec base
# DECOFF  =                 -1.0 / DCS Dec offset (asec)
# HA      = '+23:49:35.95'       / DCS Hour angle
# AIRMASS =                 1.07 / DCS Airmass
# PARANG  =                -7.64 / DCS Parallactic angle astrometric (deg)
# PARANTEL=                -7.67 / DCS Parallactic angle telescope (deg)
# EL      =                69.22 / DCS Elevation (deg)
# AZ      =                171.9 / DCS Azimuth (deg)
# LST     = '00:18:44.20'        / DCS Local sidereal time
# UT      = '13:11:51.94'        / DCS Universal Time
# DATE-OBS= '2021-08-13'         / DCS UT date of observation
# MJD     =         59439.549901 / DCS Modified Julian day
# TRACKING= 'yes     '           / DCS Servos tracking status
# GUIDING = 'true    '           / DCS Guiding status
# AUTACTIV= 'yes     '           / DCS Guider active
# AUTFWHM =             1.246848 / DCS Guider fwhm (pix)
# AUTXCENT=                -51.6 / DCS Guider x centroid (asec)
# AUTYCENT=                 25.1 / DCS Guider y centroid (asec)
# TELFOCUS=                 0.38 / DCS Telescope focus (mm)
# TELESCOP= 'Keck II '           / DCS Telescope name
# ROTSTST = 'TRACK   '           / DCS Rotator state string
# ROTSEL  = 'none    '           / DCS Selected rotator
# ROTMODE = 'position angle'     / DCS Rotator tracking mode
# ROTDEST =                  0.0 / DCS Rotator user destination (deg)
# ROTPDEST=               -61.55 / DCS Rotator physical destination (deg)
# ROTPOSN =                 0.02 / DCS Rotator user position (deg)
# ROTPPOSN=               -61.47 / DCS Rotator physical position (deg)
# ROTBASE =                -0.15 / DCS Rotator base (deg)
# ROTREFAN=                  0.0 / DCS Rotator reference angle (deg)
# ROTDETS1= '13:11:52.08'        / DCS Rotator time stamp 1
# ROTDETS2= '13:11:52.08'        / DCS Rotator time stamp 2
# SECSTST = 'INPOS   '           / DCS Secondary status string
# SECFOCUS=               -0.541 / DCS Secondary focus (mm)
# SECTHETX=               -106.2 / DCS Secondary theta x (asec)
# SECTHETY=               -352.1 / DCS Secondary theta y (asec)
# TERTSTST= 'LOCKED  '           / DCS Tertiary status string
# TERTDEST= 'rnas    '           / DCS Tertiary user destination
# TERTPOSN= 'rnas    '           / DCS Tertiary user position
# TUBETEMP=                 2.96 / DCS Tube temperature (deg C)
# DOMEPOSN=               171.74 / DCS Dome user position
# DOMESTST= 'TRACK   '           / DCS Dome status string
# FLIMAGIN= 'off     '           / DCS Dome lamp imaging mode
# FLSPECTR= 'off     '           / DCS Dome lamp spectra mode
# COMMENT The following records encapsulate the instrument state.
# COMMENT The state of the Global Server (KCWI)
# BCWAVE  =         4599.8706055 / Blue Central Wavelength (Ang)
# BPWAVE  =         4299.8583984 / Blue Peak Wavelength (Ang)
# BALPHA  =           15.1556702 / Blue grating incidence angle (deg)
# BBETA   =             7.975306 / Blue grating diffraction angle (deg)
# STATEID = '6115c23cce9e240a4bee8190' / State ID
# STATENAM= 'BL_small_4600'      / User defined state name
# PROGNAME= 'U061    '           / TAC program name
# COMMENT The state of the Blue Grating Exchanger (KBES)
# BGRATNAM= 'BL      '           / Blue Grating name
# BGRATNUM=                    2 / Blue Grating number (0-5)
# BGRANGLE=           27.9856701 / Blue Grating Angle (deg)
# BGROTNAM= '  27.986'           / Blue Grating rotator position name
# BGROTNUM=                    2 / Blue Grating rotator position num (0-2)
# BGRENC  =               -12144 / Blue Grating rotator encoder position (counts)
# BGPPOS  =                    2 / Blue Grating pusher position num (0-2)
# BGPNAME = 'Mount   '           / Blue Grating pusher position name
# BGTPOS  =                    1 / Blue Grating transfer position num (0-1)
# BGTNAME = 'Beam    '           / Blue Grating transfer position name
# BFILTNUM=                    3 / Blue Filter number (0-5)
# BFILTNAM= 'KBlue   '           / Blue Filter name
# BFPPOS  =                    2 / Blue Filter pusher position num (0-2)
# BFPNAME = 'Mount   '           / Blue Filter pusher position name
# BFTPOS  =                    1 / Blue Filter transfer position num (0-1)
# BFTNAME = 'Beam    '           / Blue Filter transfer position name
# COMMENT The state of the Blue Mechanism Server (KBMS)
# BARTANG =           22.9609756 / Blue Articulation Stage Angle (deg)
# BARTENC =               220664 / Blue Articulation Stage Encoder Value
# BNASNAM = 'Open    '           / Blue NandS Mask Stage Position Name
# BNASENC =                90010 / Blue NandS Mask Stage Encoder Value
# BFOCMM  =               -1.847 / Blue Focus Stage Position in mm
# BFOCENC =                -1847 / Blue Focus Stage Encoder Value
# BFOCHM  =                    1 / Blue Focus Stage Homed? 0-no, 1-yes
# COMMENT The state of the Calibration Unit (KCAS)
# CALTYPE = 'object  '           / Type of image according to CAL server
# HATPOS  = 'Open    '           / Instrument hatch position name
# HATNUM  =                    1 / Instrument hatch position number (0,1)
# IFUENC  =                 3059 / IFU encoder position (counts)
# IFUNUM  =                    3 / IFU position number (0-5)
# IFUNAM  = 'Small   '           / IFU position name
# CALXENC =                76177 / CAL X encoder position (counts)
# CALXPOS =                    0 / CAL X axis position number (0-13)
# CALXNAM = 'Dark    '           / CAL Y axis position number (0-13)
# CALYENC =               120337 / CAL Y encoder position (counts)
# CALYPOS =                    0 / CAL Y axis position number (0-13)
# CALYNAM = 'Dark    '           / CAL Y axis position number (0-13)
# CALPENC =                12499 / CAL Pupil encoder position (counts)
# CALPPOS =                    0 / CAL Pupil Lens position number (0-2)
# CALPNAM = 'Sky     '           / CAL Pupil Lens position name
# CALMENC =                12970 / CAL Mirror encoder position (counts)
# CALMPOS =                    0 / CAL Mirror position number (0-2)
# CALMNAM = 'Sky     '           / CAL Mirror position name
# CALHPOS =                    1 / CAL Hex Pupil position number (0-3)
# CALHNAM = 'Flat    '           / CAL Hex Pupil position name
# CALHANG =            0.0087943 / CAL Hex Pupil angle (deg)
# CALHSPD =                  0.0 / CAL Hex Pupil rotation speed (deg/s)
# CALHSTAT= 'OK      '           / CAL Hex Pupil status (Moving, OK)
# CALLENC =                 6827 / CAL Linear Polarizer encoder position (counts)
# CALLPOS =                    2 / CAL Linear Polarizer position number (0-4)
# CALLNAM = '  60.057'           / CAL Linear Polarizer position name
# CALLANG =           60.0571823 / CAL Linear Polarizer angle (deg)
# LMP0NAM = 'FeAr    '           / CAL Lamp 0 name
# LMP0STAT=                    0 / CAL Lamp 0 status (0-off, 1-on)
# LMP0SHST=                    0 / CAL Lamp 0 shutter (0-closed, 1-open)
# LMP0ONT =                  927 / CAL Lamp 0 ON duration (s)
# LMP1NAM = 'ThAr    '           / CAL Lamp 1 name
# LMP1STAT=                    0 / CAL Lamp 1 status (0-off, 1-on)
# LMP1SHST=                    0 / CAL Lamp 1 shutter (0-closed, 1-open)
# LMP1ONT =                  931 / CAL Lamp 1 ON duration (s)
# LMP2NAM = 'Aux     '           / CAL Lamp 2 name
# LMP2STAT=                    0 / CAL Lamp 2 status (0-off, 1-on)
# LMP2SHST=                    0 / CAL Lamp 2 shutter (0-closed, 1-open)
# LMP2ONT =                    0 / CAL Lamp 2 ON duration (s)
# LMP3NAM = 'Continuum A'        / CAL Lamp 3 name
# LMP3STAT=                    0 / CAL Lamp 3 status (0-off, 1-on)
# LMP3ONT =                 1094 / CAL Lamp 3 ON duration (s)
# COMMENT The state of the Rotator Server (KROS)
# ROTMODS = 'track   '           / ROS Rotation Mode(s)
# SKYPA   =                  0.0 / ROS Sky PA
# TRCKMODE=                    1 / ROS Tracking mode
# COMMENT The state of the Blue Dewar Pressure controllers (KBGS, KBVS)
# BGPRESS =               0.0016 / Blue Pressure Gauge Pressure (Torr)
# BVPRESS =                  0.0 / Blue Vac-Ion Pressure (Torr)
# BVHVON  =                    0 / Blue Vac-Ion HV on? 0-no, 1-yes
# BVCURR  =                  0.0 / Blue Vac-Ion Current (Amps)
# BVVOLT  =                    0 / Blue Vac-Ion Voltage (Volts)
# COMMENT The state of Bank A of the Temperature Controller (KT1S)
# BCCDTMP =              162.933 / Blue CCD Temperature (K)
# BHTR1ST = 'OK      '           / Blue Heater 1 Status
# BHTR2ST = 'OK      '           / Blue Heater 2 Status
# BCNTRL1 =                    1 / Blue Heater 1 Control Mode
# BCNTRL2 =                    1 / Blue Heater 2 Control Mode
# BINPUT1 =                    0 / Blue Heater 1 Input Sensor
# BINPUT2 =                    1 / Blue Heater 2 Input Sensor
# BTRGTMP1=               273.31 / Blue Heater 2 setpoint (K)
# BTRGTMP2=                163.0 / Blue Heater 2 setpoint (K)
# BRESIST1=                    1 / Blue Heater 1 Resistance (1-25, 2-50 Ohms)
# BRESIST2=                    1 / Blue Heater 2 Resistance (1-25, 2-50 Ohms)
# BPUPEN1 =                    0 / Blue Heater 1 Power-up Enabled?
# BPUPEN2 =                    1 / Blue Heater 2 Power-up Enabled?
# BMXCURM1=                    4 / Blue Heater 1 Max Current Mode
# BMXCURM2=                    1 / Blue Heater 2 Max Current Mode
# BRANGE1 =                    0 / Blue Heater 1 Power Range (0-Off, 1-Lo, 2-Md)
# BRANGE2 =                    2 / Blue Heater 2 Power Range (0-Off, 1-Lo, 2-Md)
# BTMPHTP1=                  0.0 / Blue Heater 1 Output (%)
# BTMPHTP2=                  1.8 / Blue Heater 2 Output (%)
# TMPLOCA1= 'Blue CCD A'         / Temperature Bank A, Sensor 1 name
# TMPA1   =              162.933 / Temperature Bank A, Sensor 1 value
# TMPLOCA2= 'Blue Cam B'         / Temperature Bank A, Sensor 2 name
# TMPA2   =              271.665 / Temperature Bank A, Sensor 2 value
# TMPLOCA3= 'Blue Shutter'       / Temperature Bank A, Sensor 3 name
# TMPA3   =               280.66 / Temperature Bank A, Sensor 3 value
# TMPLOCA4= 'Blue InvPl'         / Temperature Bank A, Sensor 4 name
# TMPA4   =              160.629 / Temperature Bank A, Sensor 4 value
# TMPLOCA5= 'Blue Strap Bot'     / Temperature Bank A, Sensor 5 name
# TMPA5   =              140.436 / Temperature Bank A, Sensor 5 value
# TMPLOCA6= 'Blue Strap Top'     / Temperature Bank A, Sensor 6 name
# TMPA6   =              108.003 / Temperature Bank A, Sensor 6 value
# TMPLOCA7= 'Blue Case'          / Temperature Bank A, Sensor 7 name
# TMPA7   =              276.514 / Temperature Bank A, Sensor 7 value
# TMPLOCA8= 'Bench Bot'          / Temperature Bank A, Sensor 8 name
# TMPA8   =              275.428 / Temperature Bank A, Sensor 8 value
# COMMENT The state of Bank B of the Temperature Controller (KT2S)
# RHTR1ST = 'OK      '           / Red Heater 1 Status
# RHTR2ST = 'OK      '           / Red Heater 2 Status
# RCNTRL1 =                    1 / Red Heater 1 Control Mode
# RCNTRL2 =                    1 / Red Heater 2 Control Mode
# RINPUT1 =                    1 / Red Heater 1 Input Sensor
# RINPUT2 =                    2 / Red Heater 2 Input Sensor
# RTRGTMP1=               226.85 / Red Heater 2 setpoint (K)
# RTRGTMP2=               226.85 / Red Heater 2 setpoint (K)
# RRESIST1=                    1 / Red Heater 1 Resistance (1-25, 2-50 Ohms)
# RRESIST2=                    1 / Red Heater 2 Resistance (1-25, 2-50 Ohms)
# RPUPEN1 =                    0 / Red Heater 1 Power-up Enabled?
# RPUPEN2 =                    0 / Red Heater 2 Power-up Enabled?
# RMXCURM1=                    4 / Red Heater 1 Max Current Mode
# RMXCURM2=                    3 / Red Heater 2 Max Current Mode
# RRANGE1 =                    0 / Red Heater 1 Power Range (0-Off, 1-Lo, 2-Md)
# RRANGE2 =                    0 / Red Heater 2 Power Range (0-Off, 1-Lo, 2-Md)
# RTMPHTP1=                  0.0 / Red Heater 1 Output (%)
# RTMPHTP2=                  0.0 / Red Heater 2 Output (%)
# TMPLOCB1= 'Bench Top A'        / Temperature Bank B, Sensor 1 name
# TMPB1   =              274.723 / Temperature Bank B, Sensor 1 value
# TMPLOCB2= 'IFU Base B'         / Temperature Bank B, Sensor 2 name
# TMPB2   =              277.104 / Temperature Bank B, Sensor 2 value
# TMPLOCB3= 'Cab rear'           / Temperature Bank B, Sensor 3 name
# TMPB3   =              279.161 / Temperature Bank B, Sensor 3 value
# TMPLOCB4= 'KMG Weld'           / Temperature Bank B, Sensor 4 name
# TMPB4   =              274.138 / Temperature Bank B, Sensor 4 value
# TMPLOCB5= 'Cal Base'           / Temperature Bank B, Sensor 5 name
# TMPB5   =              277.406 / Temperature Bank B, Sensor 5 value
# TMPLOCB6= 'Collim  '           / Temperature Bank B, Sensor 6 name
# TMPB6   =                274.5 / Temperature Bank B, Sensor 6 value
# TMPLOCB7= 'Cab int '           / Temperature Bank B, Sensor 7 name
# TMPB7   =              292.277 / Temperature Bank B, Sensor 7 value
# TMPLOCB8= 'Blue Fill'          / Temperature Bank B, Sensor 8 name
# TMPB8   =               221.69 / Temperature Bank B, Sensor 8 value
# COMMENT The state of Bank A of the Power Controller (KP1S)
# PWNAMEA1= 'FPCam   '           / Power Bank A, Port 1 name
# PWSTATA1=                    0 / Power Bank A, Port 1 on? 0-no, 1-yes
# PWNAMEA2= 'Magiq   '           / Power Bank A, Port 2 name
# PWSTATA2=                    1 / Power Bank A, Port 2 on? 0-no, 1-yes
# PWNAMEA3= 'Glycol  '           / Power Bank A, Port 3 name
# PWSTATA3=                    1 / Power Bank A, Port 3 on? 0-no, 1-yes
# PWNAMEA4= 'Lkshore1'           / Power Bank A, Port 4 name
# PWSTATA4=                    1 / Power Bank A, Port 4 on? 0-no, 1-yes
# PWNAMEA5= 'BPGauge '           / Power Bank A, Port 5 name
# PWSTATA5=                    1 / Power Bank A, Port 5 on? 0-no, 1-yes
# PWNAMEA6= 'BVacIon '           / Power Bank A, Port 6 name
# PWSTATA6=                    1 / Power Bank A, Port 6 on? 0-no, 1-yes
# PWNAMEA7= 'Hatch   '           / Power Bank A, Port 7 name
# PWSTATA7=                    1 / Power Bank A, Port 7 on? 0-no, 1-yes
# PWNAMEA8= 'BShutter'           / Power Bank A, Port 8 name
# PWSTATA8=                    1 / Power Bank A, Port 8 on? 0-no, 1-yes
# COMMENT The state of Bank B of the Power Controller (KP2S)
# PWNAMEB1= 'HeatExchanger'      / Power Bank B, Port 1 name
# PWSTATB1=                    1 / Power Bank B, Port 1 on? 0-no, 1-yes
# PWNAMEB2= 'BDet    '           / Power Bank B, Port 2 name
# PWSTATB2=                    1 / Power Bank B, Port 2 on? 0-no, 1-yes
# PWNAMEB3= 'AutoFill'           / Power Bank B, Port 3 name
# PWSTATB3=                    1 / Power Bank B, Port 3 on? 0-no, 1-yes
# PWNAMEB4= 'Lkshore2'           / Power Bank B, Port 4 name
# PWSTATB4=                    1 / Power Bank B, Port 4 on? 0-no, 1-yes
# PWNAMEB5= 'Lantrnx1'           / Power Bank B, Port 5 name
# PWSTATB5=                    1 / Power Bank B, Port 5 on? 0-no, 1-yes
# PWNAMEB6= 'AFFiberConvert'     / Power Bank B, Port 6 name
# PWSTATB6=                    1 / Power Bank B, Port 6 on? 0-no, 1-yes
# PWNAMEB7= 'PB2:BEX;BMS'        / Power Bank B, Port 7 name
# PWSTATB7=                    1 / Power Bank B, Port 7 on? 0-no, 1-yes
# PWNAMEB8= 'Unused  '           / Power Bank B, Port 8 name
# PWSTATB8=                    0 / Power Bank B, Port 8 on? 0-no, 1-yes
# COMMENT The state of Bank C of the Power Controller (KP3S)
# PWNAMEC1= 'CalLamps'           / Power Bank C, Port 1 name
# PWSTATC1=                    1 / Power Bank C, Port 1 on? 0-no, 1-yes
# PWNAMEC2= 'Unused  '           / Power Bank C, Port 2 name
# PWSTATC2=                    0 / Power Bank C, Port 2 on? 0-no, 1-yes
# PWNAMEC3= 'Unused  '           / Power Bank C, Port 3 name
# PWSTATC3=                    0 / Power Bank C, Port 3 on? 0-no, 1-yes
# PWNAMEC4= 'Unused  '           / Power Bank C, Port 4 name
# PWSTATC4=                    0 / Power Bank C, Port 4 on? 0-no, 1-yes
# PWNAMEC5= 'Unused  '           / Power Bank C, Port 5 name
# PWSTATC5=                    0 / Power Bank C, Port 5 on? 0-no, 1-yes
# PWNAMEC6= 'Unused  '           / Power Bank C, Port 6 name
# PWSTATC6=                    0 / Power Bank C, Port 6 on? 0-no, 1-yes
# PWNAMEC7= 'Unused  '           / Power Bank C, Port 7 name
# PWSTATC7=                    0 / Power Bank C, Port 7 on? 0-no, 1-yes
# PWNAMEC8= 'PB1:CAL;ROT'        / Power Bank C, Port 8 name
# PWSTATC8=                    1 / Power Bank C, Port 8 on? 0-no, 1-yes
# COMMENT No further records from the end of the exposure.
# COMMENT
# COMMENT ------------------------------------------------------------------------
# COMMENT End of keyheader output
# COMMENT Program start time: 2021-08-13T13:14:42.909966Z
# COMMENT Program end time:   2021-08-13T13:14:44.462946Z
# COMMENT ------------------------------------------------------------------------
# COMMENT ------------------------------------------------------------------------
# COMMENT keyheader version 96230
# COMMENT Location: /kroot/rel/default/bin/keyheader
# COMMENT Configuration: /kroot/rel/default/data/kcwi/keyheader.conf
# COMMENT Hostname: kcwitarg
# COMMENT Program start time: 2021-08-13T13:14:44.801455Z
# COMMENT ------------------------------------------------------------------------
# COMMENT
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT keyheader section [ReadoutEnd]
# COMMENT Snapshot timestamp: 2021-08-13T13:14:41.907000Z
# COMMENT - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# COMMENT
# COMMENT The following records correspond to the end of the readout,
# COMMENT as recorded in the DATEREND record.
# OUTDIR  = '/s/sdata1400/kcwi6/2021aug13' / directory path
# OUTFILE = 'kb210813_'          / filename prefix
# FRAMENO =                   39 / frame number
# COMMENT No further records from the end of the readout.
# COMMENT
# COMMENT ------------------------------------------------------------------------
# COMMENT End of keyheader output
# COMMENT Program start time: 2021-08-13T13:14:44.801455Z
# COMMENT Program end time:   2021-08-13T13:14:44.832307Z
# COMMENT ------------------------------------------------------------------------
# CHECKSUM= '5dQN7ZQN5dQN5ZQN'   / HDU checksum updated 2021-08-13T13:14:44
# DATASUM = '2528041364'         / data unit checksum updated 2021-08-13T13:14:44
# BIASRN1 =                3.049
# BIASRN2 =                2.949
# BIASSUB =                    T / master bias subtracted?
# MBFILE  = 'kb210813_00011_mbias.fits' / Master bias filename
# OSCNRN1 =                3.067 / amp1 RN in e- from oscan
# OSCNRN2 =                4.179 / amp2 RN in e- from oscan
# OSCANSUB=                    T / Overscan subtracted?
# ATSEC1  = '[1:2048,1:4112]'
# ATSEC2  = '[2049:4096,1:4112]'
# OSCANTRM=                    T / Overscan trimmed?
# GAINCOR =                    T / Gain corrected?
# BUNIT   = '1e+16 erg / (Angstrom cm2 s)' / Pixel units
# BPCLEAN =                    T / cleaned bad pixels?
# BPFILE  = 'data/defect_TUP_1x1.dat' / defect list
# NBPCLEAN=                 2319 / number of bad pixels cleaned
# CRCLEAN =                    T / cosmic rays cleaned?
# NCRCLEAN=                14195 / number of cosmic ray pixels
# UNCSTD  =                    T / stddev uncertainty created?
# IMGRECT =                    T / Image rectified?
# DARKSUB =                    F / master dark subtracted?
# SCATSUB =                    T / was scattered light subtracted?
# FLATCOR =                    T / flat corrected?
# MFFILE  = 'kb210813_00021_mflat.fits' / Master flat filename
# SKYCOR  =                    T / sky corrected?
# SKYMAST = 'kb210813_00039_sky.fits' / Master sky filename
# SKYSCL  =                  1.0 / sky scale factor
# GEOMCOR =                    T / Geometry corrected?
# BARSEP  =    27.53202446591763 / separation of bars (binned pix)
# BAR0    =                   14 / first bar pixel position
# WAVALL0 =    3329.650191979673 / Low inclusive wavelength
# WAVALL1 =    5937.065768167051 / High inclusive wavelength
# WAVGOOD0=    3645.601872316749 / Low good wavelength
# WAVGOOD1=    5627.908118211273 / High good wavelength
# WAVMID  =    4635.056487668687 / middle wavelength
# DICHFRAC=                  1.0 / Dichroic Fraction
# AVWVSIG =  0.05387544022367609 / Avg. bar wave sigma (Ang)
# SDWVSIG = 0.006196395367751129 / Stdev. var wave sigma (Ang)
# PXSCL   =            4.048E-05 / Pixel scale along slice (deg)
# SLSCL   =           9.4295E-05 / Pixel scale perp. to slices (deg)
# CBARSNO =                   18 / Continuum bars image number
# CBARSFL = 'kb210813_00018.fits' / Continuum bars image filename
# ARCNO   =                   20 / Arc image number
# ARCFL   = 'kb210813_00020.fits' / Arc image filename
# GEOMFL  = 'kb210813_00020_geom.pkl' / Geometry file
# IFUPA   =                 0.02 / IFU position angle (degrees)
# IFUROFF =                  0.0 / IFU-SKYPA offset (degrees)
# WCSDIM  =                    3 / number of dimensions in WCS
# WCSNAME = 'KCWI    '
# RADESYS = 'FK5     '
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CTYPE3  = 'WAVE    '           / Air Wavelengths
# CUNIT1  = 'deg     '           / RA units
# CUNIT2  = 'deg     '           / DEC units
# CUNIT3  = 'Angstrom'           / Wavelength units
# CNAME1  = 'KCWI RA '           / RA name
# CNAME2  = 'KCWI DEC'           / DEC name
# CNAME3  = 'KCWI Wavelength'    / Wavelength name
# CRVAL1  =    7.282291666666666 / RA zeropoint
# CRVAL2  =  -0.9320833333333333 / DEC zeropoint
# CRVAL3  =               3329.5 / Wavelength zeropoint
# CRPIX1  =                23.05 / RA reference pixel
# CRPIX2  =                101.6 / DEC reference pixel
# CRPIX3  =                  1.0 / Wavelength reference pixel
# CD1_1   = -4.0479997533817E-05 / RA degrees per column pixel
# CD2_1   = 3.29151636949255E-08 / DEC degrees per column pixel
# CD1_2   = 1.41301853371927E-08 / RA degrees per row pixel
# CD2_2   = 4.04799975338173E-05 / DEC degrees per row pixel
# CD3_3   =                  0.5 / Wavelength Angstroms per pixel
# LONPOLE =                180.0 / Native longitude of Celestial pole
# LATPOLE =                  0.0 / Native latitude of Celestial pole
# VCORR   =    18.43440064239304
# DARCOR  =                    T / DAR corrected?
# DARANG  =    7.659999999999999 / DAR projection angle (deg)
# DARPADX =                   11 / DAR X padding (pix)
# DARPADY =                   27 / DAR Y padding (pix)
# DAREFWL =    4635.056487668687 / DAR reference wl (Ang)
# EXTCOR  =                    T / extinction corrected?
# AVEXCOR =    1.235459120583041 / average extin. correction (flux ratio)
# STDCOR  =                    T / std corrected?
# MSFILE  = 'kb210813_00032_invsens.fits' / Master std filename
# MSIMNO  =                   32 / master std image number
# HISTORY kcwidrp.primitives.SubtractBias
# HISTORY kcwidrp.primitives.SubtractOverscan
# HISTORY kcwidrp.primitives.TrimOverscan
# HISTORY kcwidrp.primitives.CorrectGain
# HISTORY kcwidrp.primitives.CorrectDefects
# HISTORY Astroscrappy: cleaned cosmic rays
# HISTORY Astroscrappy params: sigclip= 4.50 sigfrac= 0.30 objlim= 4.00
# HISTORY Astroscrappy params: fsmode=median psfmodel=gauss psffwhm= 2.50
# HISTORY Astroscrappy params: sepmed=False minexptime=60.000000
# HISTORY kcwidrp.primitives.RemoveCosmicRays
# HISTORY kcwidrp.primitives.CreateUncertaintyImage
# HISTORY kcwidrp.primitives.RectifyImage
# HISTORY kcwidrp version=1.0
# HISTORY git version=v0.1.1-104-g104b265
# HISTORY git date=Tue Apr 13 09:55:30 2021 -1000
# HISTORY kcwidrp.primitives.SubtractDark
# HISTORY kcwidrp.primitives.SubtractScatteredLight
# HISTORY kcwidrp.primitives.CorrectIllumination
# HISTORY kcwidrp.primitives.SubtractSky
# HISTORY kcwidrp.primitives.MakeCube
# HISTORY kcwidrp.primitives.WavelengthCorrections
# HISTORY kcwidrp.primitives.CorrectDar
# HISTORY kcwi_correct_extin
# HISTORY kcwidrp.primitives.FluxCalibrate                                        >

# %% [markdown]
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CTYPE3  = 'WAVE    '           / Air Wavelengths
# CUNIT1  = 'deg     '           / RA units
# CUNIT2  = 'deg     '           / DEC units
# CUNIT3  = 'Angstrom'           / Wavelength units
# CNAME1  = 'KCWI RA '           / RA name
# CNAME2  = 'KCWI DEC'           / DEC name
# CNAME3  = 'KCWI Wavelength'    / Wavelength name
# CRVAL1  =    7.282291666666666 / RA zeropoint
# CRVAL2  =  -0.9320833333333333 / DEC zeropoint
# CRVAL3  =               3329.5 / Wavelength zeropoint
# CRPIX1  =                23.05 / RA reference pixel
# CRPIX2  =                101.6 / DEC reference pixel
# CRPIX3  =                  1.0 / Wavelength reference pixel
# CD1_1   = -4.0479997533817E-05 / RA degrees per column pixel
# CD2_1   = 3.29151636949255E-08 / DEC degrees per column pixel
# CD1_2   = 1.41301853371927E-08 / RA degrees per row pixel
# CD2_2   = 4.04799975338173E-05 / DEC degrees per row pixel
# CD3_3   =                  0.5 / Wavelength Angstroms per pixel

# %%
print(galaxy_cube.shape)
# Out:
# (5215, 256, 119)

# %%
h1['NAXIS3']
# Out:
# 5215

# %%
import matplotlib.pyplot as plt

# %%
# look at a central pixel
x = 59
y = 148
plt.plot(galaxy_cube[int(3900.5-3329.5):int(4000.5-3329.5),y,x]) # It's gal_lin[spectrum, y-pixel, x-pixel]

# %%
# take the wavlength range and resolution

lamRange1 = h1['CRVAL3'] + np.array([0., h1['CD3_3']*(h1['NAXIS3'] - 1)])
FWHM_gal = h1['AUTFWHM']*h1['CD3_3'] # I think this is the wrong fwhm
print(FWHM_gal) # This is like the seeing...?

pick_a_pix = galaxy_cube[:, y, x]
plt.plot(pick_a_pix)

# If the galaxy is at significant redshift, one should bring the galaxy
# spectrum roughly to the rest-frame wavelength, before calling pPXF
# (See Sec.2.4 of Cappellari 2017). In practice there is no
# need to modify the spectrum in any way, given that a red shift
# corresponds to a linear shift of the log-rebinned spectrum.
# One just needs to compute the wavelength range in the rest-frame
# and adjust the instrumental resolution of the galaxy observations.
# This is done with the following three commented lines:
#
# z = 1.23 # Initial estimate of the galaxy redshift
# lamRange1 = lamRange1/(1+z) # Compute approximate restframe wavelength range
# FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom

galaxy, logLam1, velscale = util.log_rebin(lamRange1, pick_a_pix)
galaxy = galaxy/np.median(galaxy)  # Normalize spectrum to avoid numerical issues
noise = np.full_like(galaxy, 0.0047)           # Assume constant noise per pixel here
# Out:
# 0.623424

# %%
# bring in stellar templates from xshooter

# Read the list of filenames from the Single Stellar Population library
# by Vazdekis (2010, MNRAS, 404, 1639) http://miles.iac.es/. A subset
# of the library is included for this example with permission
#vazdekis = glob.glob(ppxf_dir + '/miles_models/Mun1.30*.fits')
#FWHM_tem = 2.51  # Vazdekis+10 spectra have a constant resolution FWHM of 2.51A.
#velscale_ratio = 2  # adopts 2x higher spectral sampling for templates than for galaxy

# stellar templates from xshooter
xshooter = glob.glob('/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/xshooter_lib/all_dr2_fits/*uvb.fits')
#FWHM is different for each template
velscale_ratio = 2  # adopts 2x higher spectral sampling for templates than for galaxy


# Extract the wavelength range and logarithmically rebin one spectrum
# to a velocity scale 2x smaller than the SAURON galaxy spectrum, to determine
# the size needed for the array which will contain the template spectra.
#
hdul = fits.open(xshooter[0])
star = hdul[1].data.FLUX # spectrum is hdu[1]
h2 = hdul[0].header

lamRange2 = h2['WAVELMIN'] + np.array([0., h2['WAVELMAX']])
star_new, logLam2, velscale_temp = util.log_rebin(lamRange2, star, velscale=velscale/velscale_ratio)
templates = np.empty((star_new.size, len(xshooter)))

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   12 / length of dimension 1
# NAXIS2  =                17140 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    3 / number of table fields
# TTYPE1  = 'WAVE    '
# TFORM1  = 'E       '
# TUNIT1  = 'nm      '
# TTYPE2  = 'FLUX    '
# TFORM2  = 'E       '
# TUNIT2  = 'erg cm**(-2) s**(-1) angstrom**(-1)'
# TTYPE3  = 'ERR     '
# TFORM3  = 'E       '
# TUNIT3  = 'erg cm**(-2) s**(-1) angstrom**(-1)'
# VOCLASS = 'SPECTRUM V1.0'      / VO Data Model
# VOPUB   = 'ESO/SAF '           / VO Publishing Authority
# TITLE   = 'xsl_spectrum_X0748_uvb' / Data set title
# OBJECT  = 'NGC6838_1078'       / Machine-readable name of the star
# RA      =    298.4049166666666 / [deg] Spectroscopic target position (J2000)
# DEC     =             18.78895 / [deg] Spectroscopic target position (J2000)
# RA_FULL = '19:53:37.18'        / [HH:MM:SS.SS] Target position (J2000)
# DEC_FULL= '+18:47:20.22'       / [DD:MM:SS.SS] Target position (J2000)
# APERTURE= 0.000138888888888888 / [deg] Aperture width
# TELAPSE =    398.2511339709163 / [s] Total elapsed time
# TMID    =    56488.28072011906 / [d] MJD mid exposure
# SPEC_VAL=    427.4541729013384 / [nm] Mean wavelength
# SPEC_BW =    257.0890133648481 / [nm] Bandpass Width Wmax - Wmin
# NELEM   =                17140 / Length of data arrays
# TDMIN1  =    298.9096662189144 / Start in spectral coordinates
# TDMAX1  =    555.9986795837625 / Stop in spectral coordinates
# TUTYP1  = 'Spectrum.Data.SpectralAxis.Value' / IVOA data model element field 1
# TUCD1   = 'em.wl   '           / UCD for field 1
# TUTYP2  = 'Spectrum.Data.FluxAxis.Value' / IVOA data model element for field 2
# TUCD2   = 'phot.flux.density;em.wl;src.net;stat.uncalib' / UCD for field 2
# TUTYP3  = 'Spectrum.Data.FluxAxis.Accuracy.StatError' / IVOA data model field 3
# TUCD3   = 'stat.error;phot.flux.density;em.wl;src.net;stat.uncalib' / UCD 3
# EXTNAME = 'SPECTRUM'
# INHERIT =                    T /   Primary header keywords are inherited
# CHECKSUM= '279V348S248S248S'   / HDU checksum updated 2020-01-09T12:52:04
# DATASUM = '2762668581'         / data unit checksum updated 2020-01-09T12:52:04

# %%
hdul[1].header['SPEC_BW']/hdul[1].header['NELEM']
# Out:
# 0.014999359006117157

# %%
h2['SPEC_BIN']
# Out:
# 0.01500023416563674

# %%
# So the arcsec/pix is 0.015??

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2020-01-09'         / Date this file was written
# DISPELEM= 'UVB     '           / Dispersive element name
# SPECSYS = 'SOURCE  '           / Reference frame for spectral coordinates
# EXT_OBJ =                    F / TRUE if extended
# OBJECT  = 'NGC6838_1078'       / Machine-readable name of the star
# HNAME   = 'NGC 6838 1078'      / Humane-readable name of the star
# XSL_ID  = 'X0748   '           / X-shooter Spectral Library unique identifier
# XSL_NAME= 'X0748_U_N'          / Internal name for the science spectrum
# RA      =    298.4049166666666 / [deg] Spectroscopic target position (J2000)
# DEC     =             18.78895 / [deg] Spectroscopic target position (J2000)
# RA_FULL = '19:53:37.18'        / [HH:MM:SS.SS] Target position (J2000)
# DEC_FULL= '+18:47:20.22'       / [DD:MM:SS.SS] Target position (J2000)
# EQUINOX =               2000.0 / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate reference frame
# WAVELMIN=    298.9096662189144 / [nm] Minimum wavelength
# WAVELMAX=    555.9986795837625 / [nm] Maximum wavelength
# SPEC_BIN=  0.01500023416563674 / Average spectral coordinate bin size
# CONTNORM=                    F / TRUE if normalised to the continuum
# TOT_FLUX=                    F / TRUE if photometric conditions
# FLUXERR =                 -1.0 / Uncertainty in flux scale (%)
# SNR     =                36.91 / Median signal-to-noise ratio
# SPEC_RES=          9765.211866 / Reference spectral resolving power
# ORIGIN  = 'ESO     '           / European Southern Observatory
# TELESCOP= 'ESO-VLT-U2'         / ESO Telescope designation
# INSTRUME= 'XSHOOTER'           / Instrument used
# PROG_ID = '189.B-0925(C)'      / ESO program identification
# OBID1   =               929647 / Observation block ID
# M_EPOCH =                    F / True if combination of multiple epochs
# SINGLEXP=                    F / True if resulting from single exposure
# OBSTECH = 'ECHELLE,SLIT,NODDING' / Observation technique
# FLUXCAL = 'UNCALIBRATED'       / Quality of flux calibration
# PRODCATG= 'SCIENCE.SPECTRUM'   / Single target 1-dimensional spectrum
# PROCSOFT= 'xshoo/2.6.8'        / Pipeline (unique) identifier
# NCOMBINE=                    2 / Number of raw science data files combined
# PROV1   = 'XSHOO.2013-07-15T06:40:55.092' / Originating raw science file
# PROV2   = 'XSHOO.2013-07-15T06:45:10.943' / Originating raw science file
# EXPTIME =           284.799996 / Integration time
# TEXPTIME=           284.799996 / Total integration time of all exposures
# FWHM    =                 2.74 / Observatory seeing queried from AS
# MJD-OBS =      56488.278415425 / Start of the observations
# MJD-END =    56488.28302481312 / End of the observations
# EXT_AVG =                    T / Two 1D-spectra averaged
# CAL_NAME= 'CAL0135_X0748_U_S_I.fits' / Internal name for the response curve
# CAL_STAR= 'EG274 V11.03'       / Spectro-photometric standard star target
# CAL_RAW1= 'XSHOO.2013-07-14T22:48:58.171' / Originating raw flux-standard file
# CAL_RAW2= 'XSHOO.2013-07-14T22:53:19.623' / Originating raw flux-standard file
# FLUX_COR=                    T / First flux calibration applied
# LOSS_COR=                    T / TRUE if correction for slit loss was applied
# STA_NAME= 'X0748_U_S_F.fits'   / Internal name for the wide-slit spectrum
# STA_RAW1= 'XSHOO.2013-07-15T06:37:29.376' / Originating raw wide-slit file
# REST_COR=                    T / TRUE if correction for rest-frame was applied
# REST_VAL=  0.07000000000000001 / cz value in km/s
# BARY_COR=                 4.75 / Barycentric radial velocity correction value
# WAVY_UVB=                    F / Wavy spectrum between 460 and 520 nm
# WMIN_UVB= '320     '           / Shortest useful wavelength [in nm]
# REFERENC= 'Gonneau et al. 2019' / Bibliographic reference
# CHECKSUM= 'laABnR9AlXAAlX7A'   / HDU checksum updated 2020-01-09T12:52:04
# DATASUM = '0       '           / data unit checksum updated 2020-01-09T12:52:04

# %%
# FWHM_gal is apparently much less than FWHM_tem...

# %%
FWHM_tem
# Out:
# 2.74

# %%
FWHM_gal
# Out:
# 0.623424

# %%
# gather the templates, rebin

for j, file in enumerate(xshooter):
    hdul = fits.open(file)
    star = hdu[1].data.FLUX
    
    print(star[0])
    # Quadratic sigma difference in pixels Vazdekis --> SAURON
    # The formula below is rigorously valid if the shapes of the
    # instrumental spectral profiles are well approximated by Gaussians.
    #
    FWHM_tem = h2['FWHM']
    print(FWHM_tem)
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    print(FWHM_dif)
    sigma = FWHM_dif/2.355/h2['SPEC_BIN']  # Sigma difference in pixels # 2.355*sigma is the fwhm for gaussian?

    print(sigma)
    
    star = ndimage.gaussian_filter1d(star, sigma)
    star_new, logLam2, velscale_temp = util.log_rebin(lamRange2, star, velscale=velscale/velscale_ratio)
    templates[:, j] = star_new/np.median(star_new)  # Normalizes templates
# Out:
# 1.1041154e-11
# 2.74
# nan
# nan
# /local/shawnknabel/anaconda3/envs/astroconda/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_424612/3067145914.py in <module>
#      18     print(sigma)
#      19
# ---> 20     star = ndimage.gaussian_filter1d(star, sigma)
#      21     star_new, logLam2, velscale_temp = util.log_rebin(lamRange2, star, velscale=velscale/velscale_ratio)
#      22     templates[:, j] = star_new/np.median(star_new)  # Normalizes templates
#
# /local/shawnknabel/anaconda3/envs/astroconda/lib/python3.7/site-packages/scipy/ndimage/filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     212                       mode="reflect", cval=0.0, truncate=4.0):
#     213     """1-D Gaussian filter.
# --> 214
#     215     Parameters
#     216     ----------
#
# ValueError: cannot convert float NaN to integer

# %%
#!/usr/bin/env python
##############################################################################
#
# Usage example for the procedure PPXF, which implements the
# Penalized Pixel-Fitting (pPXF) method originally described in
# Cappellari M., & Emsellem E., 2004, PASP, 116, 138
#     http://adsabs.harvard.edu/abs/2004PASP..116..138C
# and upgraded in Cappellari M., 2017, MNRAS, 466, 798
#     http://adsabs.harvard.edu/abs/2017MNRAS.466..798C
#
# The example also shows how to include a library of templates
# and how to mask gas emission lines if present.
#
# MODIFICATION HISTORY:
#   V1.0.0: Written by Michele Cappellari, Leiden 11 November 2003
#   V1.1.0: Log rebin the galaxy spectrum. Show how to correct the velocity
#       for the difference in starting wavelength of galaxy and templates.
#       MC, Vicenza, 28 December 2004
#   V1.1.1: Included explanation of correction for instrumental resolution.
#       After feedback from David Valls-Gabaud. MC, Venezia, 27 June 2005
#   V2.0.0: Included example routine to determine the goodPixels vector
#       by masking known gas emission lines. MC, Oxford, 30 October 2008
#   V2.0.1: Included instructions for high-redshift usage. Thanks to Paul Westoby
#       for useful feedback on this issue. MC, Oxford, 27 November 2008
#   V2.0.2: Included example for obtaining the best-fitting redshift.
#       MC, Oxford, 14 April 2009
#   V2.1.0: Bug fix: Force PSF_GAUSSIAN to produce a Gaussian with an odd
#       number of elements centered on the middle one. Many thanks to
#       Harald Kuntschner, Eric Emsellem, Anne-pMarie Weijmans and
#       Richard McDermid for reporting problems with small offsets
#       in systemic velocity. MC, Oxford, 15 February 2010
#   V2.1.1: Added normalization of galaxy spectrum to avoid numerical
#       instabilities. After feedback from Andrea Cardullo.
#       MC, Oxford, 17 March 2010
#   V2.2.0: Perform templates convolution in linear wavelength.
#       This is useful for spectra with large wavelength range.
#       MC, Oxford, 25 March 2010
#   V2.2.1: Updated for Coyote Graphics. MC, Oxford, 11 October 2011
#   V2.2.2: Renamed PPXF_KINEMATICS_EXAMPLE_SAURON to avoid conflict with the
#       new PPXF_KINEMATICS_EXAMPLE_SDSS. Removed DETERMINE_GOOPIXELS which was
#       made a separate routine. MC, Oxford, 12 January 2012
#   V3.0.0: Translated from IDL into Python. MC, Oxford, 6 December 2013
#   V3.0.1: Support both Python 2.6/2.7 and Python 3.x. MC, Oxford, 25 May 2014
#   V3.0.2: Explicitly sort template files as glob() output may not be sorted.
#       Thanks to Marina Trevisan for reporting problems under Linux.
#       MC, Sydney, 4 February 2015
#   V3.0.3: Use redshift in determine_goodpixels. MC, Oxford, 5 May 2015
#   V3.0.4: Support both Pyfits and Astropy to read FITS files.
#       MC, Oxford, 22 October 2015
#   V3.1.0: Replaced the Vazdekis-99 SSP models with the Vazdekis+10 ones.
#       MC, Oxford, 3 May 2016
#   V3.1.1: Illustrate how to use a higher sampling for the template, via the
#       `velscale_ratio` keyword. MC, Oxford, 22 June 2016
#   V3.1.2: Use proper input `vsyst` when `velscale_ratio` > 1.
#       Thanks to Kyle Westfall for finding this issue in the MaNGA DAP.
#       MC, Oxford, 19 October 2016
#   V3.1.3: Make files paths relative to this file, to run the example from
#       any directory. MC, Oxford, 18 January 2017
#   V3.1.4: Updated text on the de-redshifting of the spectrum.
#       MC, Oxford, 5 October 2017
#   V3.1.5: Changed imports for pPXF as a package.
#       Make file paths relative to the pPXF package to be able to run the
#       example unchanged from any directory. MC, Oxford, 17 April 2018
#   V3.1.6: Dropped legacy Python 2.7 support. MC, Oxford, 10 May 2018
#   V3.1.7: Fixed clock DeprecationWarning in Python 3.7.
#       MC, Oxford, 27 September 2018
#
##############################################################################

import glob
from os import path
from time import perf_counter as clock

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

def ppxf_example_kinematics_kcwi():

    #ppxf_dir = path.dirname(path.realpath(ppxf_package.__file__))
    kin_dir = '/local/shawnknabel/slacs_kinematics/'

    # Read a galaxy spectrum and define the wavelength range
    #
    file = f'{kin_dir}KCWI_J0029_icubes_mosaic_0.1457.fits' #ppxf_dir + '/spectra/NGC4550_SAURON.fits'
    hdu = fits.open(file)
    gal_lin = hdu[0].data
    h1 = hdu[0].header
    
    print(gal_lin.shape)
    print(h1)
    

    lamRange1 = h1['CRVAL1'] + np.array([0., h1['CDELT1']*(h1['NAXIS1'] - 1)])
    FWHM_gal = 4.2  # SAURON has an instrumental resolution FWHM of 4.2A.

    # If the galaxy is at significant redshift, one should bring the galaxy
    # spectrum roughly to the rest-frame wavelength, before calling pPXF
    # (See Sec.2.4 of Cappellari 2017). In practice there is no
    # need to modify the spectrum in any way, given that a red shift
    # corresponds to a linear shift of the log-rebinned spectrum.
    # One just needs to compute the wavelength range in the rest-frame
    # and adjust the instrumental resolution of the galaxy observations.
    # This is done with the following three commented lines:
    #
    # z = 1.23 # Initial estimate of the galaxy redshift
    # lamRange1 = lamRange1/(1+z) # Compute approximate restframe wavelength range
    # FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom

    galaxy, logLam1, velscale = util.log_rebin(lamRange1, gal_lin)
    galaxy = galaxy/np.median(galaxy)  # Normalize spectrum to avoid numerical issues
    noise = np.full_like(galaxy, 0.0047)           # Assume constant noise per pixel here

    # Read the list of filenames from the Single Stellar Population library
    # by Vazdekis (2010, MNRAS, 404, 1639) http://miles.iac.es/. A subset
    # of the library is included for this example with permission
    vazdekis = glob.glob(ppxf_dir + '/miles_models/Mun1.30*.fits')
    FWHM_tem = 2.51  # Vazdekis+10 spectra have a constant resolution FWHM of 2.51A.
    velscale_ratio = 2  # adopts 2x higher spectral sampling for templates than for galaxy

    # Extract the wavelength range and logarithmically rebin one spectrum
    # to a velocity scale 2x smaller than the SAURON galaxy spectrum, to determine
    # the size needed for the array which will contain the template spectra.
    #
    hdu = fits.open(vazdekis[0])
    ssp = hdu[0].data
    h2 = hdu[0].header
    lamRange2 = h2['CRVAL1'] + np.array([0., h2['CDELT1']*(h2['NAXIS1'] - 1)])
    sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
    templates = np.empty((sspNew.size, len(vazdekis)))

    # Convolve the whole Vazdekis library of spectral templates
    # with the quadratic difference between the SAURON and the
    # Vazdekis instrumental resolution. Logarithmically rebin
    # and store each template as a column in the array TEMPLATES.

    # Quadratic sigma difference in pixels Vazdekis --> SAURON
    # The formula below is rigorously valid if the shapes of the
    # instrumental spectral profiles are well approximated by Gaussians.
    #
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/h2['CDELT1']  # Sigma difference in pixels

    for j, file in enumerate(vazdekis):
        hdu = fits.open(file)
        ssp = hdu[0].data
        ssp = ndimage.gaussian_filter1d(ssp, sigma)
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates[:, j] = sspNew/np.median(sspNew)  # Normalizes templates

    # The galaxy and the template spectra do not have the same starting wavelength.
    # For this reason an extra velocity shift DV has to be applied to the template
    # to fit the galaxy spectrum. We remove this artificial shift by using the
    # keyword VSYST in the call to PPXF below, so that all velocities are
    # measured with respect to DV. This assume the redshift is negligible.
    # In the case of a high-redshift galaxy one should de-redshift its
    # wavelength to the rest frame before using the line below (see above).
    #
    c = 299792.458
    dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c  # km/s

    z = 0.0015  # Initial redshift estimate of the galaxy
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)

    # Here the actual fit starts. The best fit is plotted on the screen.
    # Gas emission lines are excluded from the pPXF fit using the GOODPIXELS keyword.
    #
    vel = c*np.log(1 + z)   # eq.(8) of Cappellari (2017)
    start = [vel, 200.]  # (km/s), starting guess for [V, sigma]
    t = clock()

    pp = ppxf(templates, galaxy, noise, velscale, start,
              goodpixels=goodPixels, plot=True, moments=4,
              degree=4, vsyst=dv, velscale_ratio=velscale_ratio)

    print("Formal errors:")
    print("     dV    dsigma   dh3      dh4")
    print("".join("%8.2g" % f for f in pp.error*np.sqrt(pp.chi2)))

    print('Elapsed time in pPXF: %.2f s' % (clock() - t))

    # If the galaxy is at significant redshift z and the wavelength has been
    # de-redshifted with the three lines "z = 1.23..." near the beginning of
    # this procedure, the best-fitting redshift is now given by the following
    # commented line (equation 2 of Cappellari et al. 2009, ApJ, 704, L34;
    # http://adsabs.harvard.edu/abs/2009ApJ...704L..34C)
    #
    # print('Best-fitting redshift z:', (z + 1)*(1 + pp.sol[0]/c) - 1)

#------------------------------------------------------------------------------

if __name__ == '__main__':

    ppxf_example_kinematics_sauron()
    import matplotlib.pyplot as plt
    plt.pause(1)
# Out:
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:       436       113     0.032     0.066
# chi2/DOF: 1.015; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  9 / 150
# Formal errors:
#      dV    dsigma   dh3      dh4
#      2.4     5.2   0.018   0.032
# Elapsed time in pPXF: 0.84 s
