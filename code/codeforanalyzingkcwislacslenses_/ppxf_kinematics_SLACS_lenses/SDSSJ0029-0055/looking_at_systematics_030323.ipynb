# %% [markdown]
# # 03/03/23 - This notebook looks at systematics for the "initial try" of Fateful Disaster Pt 2 redoing systematics with g-band, etc., strategizing for how to put it all together.
# # Uses the script "final_kinematics_covariance.py
# # This should be ready to put back into the script.

# %%
# 
from astropy.io import fits
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from scipy.optimize import curve_fit
from statsmodels.stats.correlation_tools import cov_nearest
import pathlib # to create directory
from datetime import date
today = date.today().strftime('%d%m%y')
from time import perf_counter as timer
import glob
import pickle
# register first tick
tick = timer()
from pathlib import Path # to create directory


#################################################
# objects
obj_names = ['SDSSJ0029-0055',
             'SDSSJ0037-0942',
             'SDSSJ0330-0020',
             'SDSSJ1112+0826',
             'SDSSJ1204+0358',
             'SDSSJ1250+0523',
             'SDSSJ1306+0600',
             'SDSSJ1402+6321',
             'SDSSJ1531-0105',
             'SDSSJ1538+5817',
             'SDSSJ1621+3931',
             'SDSSJ1627-0053',
             'SDSSJ1630+4520',
             'SDSSJ2303+1422'
            ]

#################################################
# functions specific to this script

def weighted_gaussian(xx, mu, sig, c2):
    yy = np.zeros(shape=xx.shape)
    for i in range(len(xx)):
        yy[i] = np.exp(-np.power(xx[i] - mu, 2.) / (2 * np.power(sig, 2.))) * np.exp(-0.5 * c2)
    return yy

def estimate_systematic_error (k_solutions, velocity, random_error, chi2, vel_moment, plot=True):
    
    # take x axis to be the 81 solutions
    x = np.arange(k_solutions)
    # y axis the velocity measurement
    y = velocity
    dy = random_error
    
    if plot==True:
        f, axarr = plt.subplots(1)
        # plot the 81 velocity disperions with error bars
        axarr.errorbar(x, y, yerr=dy, fmt='o', color='black',
                  ecolor='lightgray', elinewidth=1, capsize=0)
        f.set_size_inches(12, 2)
        plt.xlabel('Solution #')
        if vel_moment == 'VD':
            plt.ylabel(r'$\sigma$ km/s')
        elif vel_moment == 'V':
            plt.ylabel('Velocity km/s')
        plt.tight_layout()
        plt.show()
    
    # take velocity bounds
    vel_min = y.min() - dy.max() * 3
    vel_max = y.max() + dy.max() * 3
    
    # sum by weighted velocity disperions profiles
    xx = np.linspace(vel_min, vel_max, 1000)
    c2 = chi2

    if plot==True:
        plt.figure(figsize=(8,6))
        if vel_moment == 'VD':
            plt.xlabel(r'$\sigma$ km/s')
        elif vel_moment == 'V':
            plt.xlabel('Velocity km/s')
    
    sum_gaussians = np.zeros(shape=xx.shape)
    
    for i in range(len(y)):
        yy = weighted_gaussian(xx, y[i], dy[i], c2[i]) 
        if plot==True:
            plt.plot(xx, yy)    
        sum_gaussians += yy
    
    if plot==True:
        plt.show()
    
    max_likelihood = xx[sum_gaussians.argmax()]
    
    # calculate initial guess for Gaussian fit
    mu_0 = y.mean()
    sigma_0 = dy.mean()
    amp_0 = sum_gaussians.max()

    # fit the summed profile with a Gaussian to get sigma for the bin
    parameters, covariance = curve_fit(weighted_gaussian, xx, sum_gaussians, p0=[mu_0, sigma_0, amp_0])

    # take the parameters for plotting
    fit_mu = parameters[0]
    fit_sigma = parameters[1]
    fit_amp = parameters[2]
    fit_y = weighted_gaussian(xx, fit_mu, fit_sigma, fit_amp)

    # check if max_likelihood and fit_mu are super far apart
    if abs(max_likelihood - fit_mu) > 5:
        print('Check this fit...')
    # plot it all
    
    if plot==True:
        plt.figure(figsize=(8,6))

        for i in range(len(y)):
            yy = weighted_gaussian(xx, y[i], dy[i], c2[i]) 
            plt.plot(xx, yy)    

        plt.plot(xx, sum_gaussians, '-', c='b', label='sum of gaussians')
        plt.axvline(max_likelihood, c='b', linestyle='--', label=f'Max likelihood {np.around(max_likelihood, 2)}')
        plt.plot(xx, fit_y, '-', c='k', label='Gaussian fit to the sum')
        plt.axvline(fit_mu, linestyle='--', c='k', label=f'mean {np.around(fit_mu, 2)}')
        plt.axvline(fit_mu - fit_sigma, linestyle=':', c='k', label=f'sigma {np.around(fit_sigma, 2)}')
        plt.axvline(fit_mu + fit_sigma, linestyle=':', c='k')
        if vel_moment == 'VD':
            plt.xlabel(r'$\sigma$ km/s')
        elif vel_moment == 'V':
            plt.xlabel('Velocity km/s')
        plt.xlabel(r'$\sigma$ km/s')
        plt.legend(loc='upper left')
        plt.show()
        
    return fit_mu, fit_sigma


def estimate_covariance (vel1, vel2, mu1, mu2, chi2_1, chi2_2):
    # calculate covariance matrix from individual solution means (vel1 and vel2) as arrays #### Something is wrong, I should be estimating covariance between bins
    # and sample means (mu1, mu2) weighted by product of normalized likelihoods (not correct..)
    likelihood_1 = np.exp( -1/2 * (chi2_1)) # chi2_1 is 81 chi2 for bin 1, so likelihood_1 is 81 likelihoods for bin 1
    normalized_likelihood_1 = likelihood_1/np.sum(likelihood_1)
    likelihood_2 = np.exp( -1/2 * (chi2_2))
    normalized_likelihood_2 = likelihood_2/np.sum(likelihood_2)
    covariance = np.sum( (vel1 - mu1) * (vel2 - mu2) * np.sqrt(normalized_likelihood_1 * normalized_likelihood_2) )
    covariance_2 = np.mean( (vel1 - mu1) * (vel2 - mu2) )
    return covariance#, covariance_2


class MidpointNormalize(mcolors.Normalize):
    def __init__(self, vmin, vmax, midpoint=0, clip=False):
        self.midpoint = midpoint
        mcolors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        normalized_min = max(0, 1 / 2 * (1 - abs((self.midpoint - self.vmin) / (self.midpoint - self.vmax))))
        normalized_max = min(1, 1 / 2 * (1 + abs((self.vmax - self.midpoint) / (self.midpoint - self.vmin))))
        normalized_mid = 0.5
        x, y = [self.vmin, self.midpoint, self.vmax], [normalized_min, normalized_mid, normalized_max]
        return np.ma.masked_array(np.interp(value, x, y))
    
# write a function for getting, sorting, and saving the global template velocities

def create_glob_temp_velocities_array (save_dir, save=True):

    glob_temp_velocities = np.zeros(81)
    models_names = np.zeros(81).astype(str)

    i = 0
    for file in glob.glob(f'{save_dir}**/*l*.pkl'):
        model = file[-41:-33]
        file = open(file,'rb') 
        picle = pickle.load(file)
        glob_temp_velocities[i] = picle.sol[0]
        models_names[i] = model
        i = i+1
    
    glob_temp_vel_sort = np.column_stack((glob_temp_velocities, models_names))
    glob_temp_vel_sort = glob_temp_vel_sort[glob_temp_vel_sort[:,1].argsort()]
    
    glob_temp_vel_array = glob_temp_vel_sort[:,0].astype(float)
    if save == True:
        np.savetxt(f'{save_dir}glob_temp_vel_array.txt', glob_temp_vel_array, delimiter=',')
    
    return glob_temp_vel_array

def is_pos_semidef(x):
    return np.all(np.linalg.eigvals(x) >= 0)

# %%
#------------------------------------------------------------------------------
# Directories and files

# "date_of_kin" is initial try
date_of_kin = 'initial_try'

# data directory
data_dir = '/data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/'
tables_dir = f'{data_dir}tables/'
mosaics_dir = f'{data_dir}mosaics/'
kinematics_full_dir = f'{data_dir}kinematics/'
kinematics_dir =f'{kinematics_full_dir}{date_of_kin}/'
print(f'Outputs will be in {kinematics_dir}')
print()

#------------------------------------------------------------------------------
# Kinematics systematics choices

# target SN for voronoi binning
vorbin_SN_targets = np.array([10, 15, 20])

# include G band or no
g_bands = ['no_g','g_band']
# Out:
# Outputs will be in /data/raw_data/KECK_KCWI_SLACS_kinematics_shawn/kinematics/initial_try/

# %% [markdown]
# # We're only looking at J0029 right now to make sure it all works.

# %%
obj_name = obj_names[0]

print('#####################################################')
print('#####################################################')
print()
print(f'Beginning final kinematics script for object {obj_name}.')
print()

# set abbreviation for directories
obj_abbr = obj_name[4:9] # e.g. J0029

#------------------------------------------------------------------------------
# object-specific directories

mos_dir = f'{mosaics_dir}{obj_name}/' 
kin_dir = f'{kinematics_dir}{obj_name}/'

#KCWI mosaic datacube
mos_name = f'KCWI_{obj_abbr}_icubes_mosaic_0.1457'

for vorbin_SN_target in vorbin_SN_targets:
    target_dir = f'{kin_dir}target_sn_{vorbin_SN_target}/'
    syst_dir = f'{target_dir}systematics/'
    # make new directory for outputs
    fin_kin_dir = f'{target_dir}{obj_name}_final_kinematics/'
    Path(fin_kin_dir).mkdir(parents=True, exist_ok=True)

    print('################################################')
    print('################################################')
    print()
    print('Working with S/N target ', vorbin_SN_target)
    print()
    print('################################################')
    print('################################################')

    '''
    Step 0: input the necessary information of the datacube
    ''' 

    ## import voronoi binning data
    voronoi_binning_data = fits.getdata(target_dir +'voronoi_binning_' + obj_name + '_data.fits')
    N = voronoi_binning_data.shape[0] # for saving the systematics measurements

    '''
    Step 8: systematics tests
    '''

    # iterate over G-band and not G-band
    for g_band in g_bands:

        if (obj_abbr=='J0330') & (g_band=='g_band'):
            print('J0330 does not get G band')
            continue

        print()
        print('Working with ', g_band)
        print() 

        # first create G-band and no_G directories in final kineamtics
        syst_g_dir = f'{syst_dir}{g_band}/'
        fin_g_dir = f'{fin_kin_dir}{g_band}/' # in final kinematics
        Path(fin_g_dir).mkdir(parents=True, exist_ok=True)

        # bring in systematics data
        V = np.genfromtxt(f'{syst_g_dir}{obj_name}{g_band}_systematics_V.txt', delimiter=',')
        VD = np.genfromtxt(f'{syst_g_dir}{obj_name}{g_band}_systematics_VD.txt', delimiter=',')
        dV = np.genfromtxt(f'{syst_g_dir}{obj_name}{g_band}_systematics_dV.txt', delimiter=',')
        dVD = np.genfromtxt(f'{syst_g_dir}{obj_name}{g_band}_systematics_dVD.txt', delimiter=',')
        chi2 = np.genfromtxt(f'{syst_g_dir}{obj_name}{g_band}_systematics_chi2.txt', delimiter=',')

        # calculate and save global template velocities (for ea of 81 models) for velocity subtraction
        global_template_velocities = create_glob_temp_velocities_array( syst_g_dir )
        ################
        ####### subtract the global template velocities from each bin velocity (row)
        # create grid of global template velocities (num_bins, 81)
        glob_temp_vel_grid, _ = np.meshgrid(global_template_velocities, V[:,0])
        # subtract global template velocities from V
        V = V - glob_temp_vel_grid
        ################
        ####### 09/15/22 - NEW! 
        # calculate Vrms from VD and V
        Vrms = np.sqrt(V**2 + VD**2)
        dVrms = Vrms * (V*dV + VD*dVD)/(V**2 + VD**2)

        ###########
        # calculate velocities
        velocity_dispersions = np.zeros(len(VD))
        VD_sigmas = np.zeros(len(VD))
        velocities = np.zeros(len(V))
        V_sigmas = np.zeros(len(V))
        rms_velocities = np.zeros(len(Vrms))
        Vrms_sigmas = np.zeros(len(Vrms))


        for vel_moment in ['VD','V','Vrms']: ### ignore the velocities for now
        #for vel_moment in ['V','Vrms']: ### ignore the velocities for now

            if vel_moment == 'VD':
                velocity_measurements = velocity_dispersions
                vel = VD
                sigmas = VD_sigmas
                dvel = dVD
            elif vel_moment == 'V':
                velocity_measurements = velocities
                vel = V
                sigmas = V_sigmas
                dvel = dV
            elif vel_moment == 'Vrms':
                velocity_measurements = rms_velocities
                vel = Vrms
                sigmas = Vrms_sigmas
                dvel = dVrms


            print(f'Calculating {vel_moment}s and sigmas')
            print()
            print()
            
            vel_mom_name = f'{vorbin_SN_target}_{g_band}_{vel_moment}'

            for i in range(len(vel)): # vel[i] is 81 velocities in ith bin...

                ##### 09/15/22 - Doing this to the whole array before this step
                # if vel_moment=V, correct for global template velocity
                #if vel_moment == 'V':
                #    vel[i] = vel[i] - global_template_velocities

                print('###################')
                print(f'Bin number {i}')
                velocity_measurements[i], sigmas[i] = estimate_systematic_error(81, vel[i], dvel[i], chi2[i],
                                                                                vel_moment,
                                                                                plot=False)
                print(velocity_measurements[i])

            # save velocity measurements
            np.savetxt(f'{fin_g_dir}{obj_name}_{vel_mom_name}_binned.txt', 
                       velocity_measurements,
                       delimiter=',')

            ####################################
            # calculate covariance matrix

            covariance_matrix = np.zeros((len(vel), len(vel)))

            for i in range(len(vel)):
                for j in range(len(vel)):
                    if j == i:
                        covariance_matrix[i,j] = sigmas[i]**2
                    else:
                        covariance_matrix[i,j] = estimate_covariance (vel[i], vel[j], 
                                                                      velocity_measurements[i], 
                                                                      velocity_measurements[j], 
                                                                      chi2[i], 
                                                                      chi2[j])

            # check if covariance matrix is positive semi-definite, correct if not                            
            if is_pos_semidef(covariance_matrix) != True:
                print('Approximating closest positive semi-definite covariance matrix')
                covariance_matrix = cov_nearest(covariance_matrix)
                if is_pos_semidef(covariance_matrix):
                    cov_matrix_header = 'This covariance matrix has been smoothed to the closest positive semi-definite covariance matrix'
                else:
                    print('Approximating again with lower threshold')
                    covariance_matrix = cov_nearest(covariance_matrix, threshold=1e-13)
                    cov_matrix_header = 'This covariance matrix has been smoothed to the closest positive semi-definite covariance matrix'
                # if still not true, save it, note it, move on
                if is_pos_semidef(covariance_matrix) != True:
                    cov_matrix_header = 'This covariance matrix is not positive semi-definite'
                    print(f"covariance matrix still not positive semi-definite, take a closer look - {fin_g_dir}{obj_name}_covariance_matrix_{vel_moment}.txt")
                    with numpy.printoptions(threshold=numpy.inf): # print it so you can see
                        print(cov_matrix)
                # save covariance matrix
                np.savetxt(f'{fin_g_dir}{obj_name}_covariance_matrix_{vel_moment}.txt', covariance_matrix,
                           delimiter=',', header=cov_matrix_header)
                

            else:
                # save covariance matrix
                np.savetxt(f'{fin_g_dir}{obj_name}_{vel_mom_name}_covariance_matrix.txt', covariance_matrix,
                           delimiter=',')

            # normalize plotting colorbar
            vmin = np.min(covariance_matrix)
            vmax = np.max(covariance_matrix)
            print('Colorbar... vmin and vmax ', vmin, vmax)
            if vmin < 0:
                norm = MidpointNormalize(vmin=vmin, vmax=vmax, midpoint=0)
                cmap = 'seismic'
            elif vmin >= 0:
                norm = None
                cmap = 'Reds'
            else:
                print('Colorbar problem... vmin and vmax ', vmin, vmax)

            plt.figure(figsize=(16,16))
            plt.imshow(covariance_matrix, cmap='seismic', norm=norm)
            plt.title(f'{obj_name} {vel_moment} covariance matrix', fontsize=16)
            plt.xlabel('bin #', fontsize=16)
            plt.ylabel('bin #', fontsize=16)
            plt.xticks(fontsize=16)
            plt.yticks(fontsize=16)
            plt.colorbar()
            plt.savefig(f'{fin_g_dir}{obj_name}_{vel_mom_name}_covariance_matrix_visual.pdf')
            plt.savefig(f'{fin_g_dir}{obj_name}_{vel_mom_name}_covariance_matrix_visual.png')

            ##################################
            # show it without the diagonal for easier view of the covariance terms

            covariance_without_diagonal = covariance_matrix - np.diagonal(covariance_matrix)*np.identity(len(covariance_matrix))

            # normalize plotting colorbar
            vmin = np.min(covariance_without_diagonal)
            vmax = np.max(covariance_without_diagonal)
            print('Colorbar... vmin and vmax ', vmin, vmax)
            if vmin < 0:
                norm = MidpointNormalize(vmin=vmin, vmax=vmax, midpoint=0)
                cmap = 'seismic'
            elif vmin >= 0:
                norm = None
                cmap = 'Reds'
            else:
                print('Colorbar problem... vmin and vmax ', vmin, vmax)

            plt.figure(figsize=(16,16))
            plt.imshow(covariance_without_diagonal, cmap='seismic', norm=norm)
            plt.title(f'{obj_name} {vel_moment} covariance matrix', fontsize=16)
            plt.xlabel('bin #', fontsize=16)
            plt.ylabel('bin #', fontsize=16)
            plt.xticks(fontsize=16)
            plt.yticks(fontsize=16)
            plt.colorbar()

            plt.savefig(f'{fin_g_dir}{obj_name}_{vel_mom_name}_covariance_matrix_no_diag_visual.pdf')
            plt.savefig(f'{fin_g_dir}{obj_name}_{vel_mom_name}_covariance_matrix_no_diag_visual.png')

            print()
            print('####################################')
            print()
            print(f'{vel_moment} finished.')
            print()
        print('####################################')
        print('####################################')
        print()
        print(f'{obj_name} finished.')
        print()

        tock=timer()
        time_elapsed=(tock-tick)/3600 # hours
        print(f'Time elapsed: {time_elapsed} hours.')
        print()

    print('#################################################')
    print('#################################################')
    print('#################################################')

    print()
    print('Script complete.')
# Out:
# #####################################################
# #####################################################
#
# Beginning final kinematics script for object SDSSJ0029-0055.
#
# ################################################
# ################################################
#
# Working with S/N target  10
#
# ################################################
# ################################################
#
# Working with  no_g
#
# [[ -0.2891378   -0.33446167  -0.46943323 ...  -2.77502897  -2.68958502
#    -2.69511381]
#  [  1.9935863    0.45561286   5.56597009 ...   0.41764521   0.49845859
#     3.56345046]
#  [  2.61080976  -1.08461651   4.96444783 ...   0.17990658  -2.10434408
#     2.57235714]
#  ...
#  [-23.23704639 -35.85902318 -30.2556448  ... -19.22251496 -32.43411584
#   -40.02033028]
#  [-12.58096267 -29.20652843 -28.68071758 ... -10.86994126 -29.38522524
#   -31.39550456]
#  [  0.55665191  -2.30221905  -2.81602881 ...  -0.67687596  -5.8704471
#    -4.42182306]]
# Calculating VDs and sigmas
#
#
# ###################
# Bin number 0
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 208.90546937691616
# ###################
# Bin number 1
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: overflow encountered in exp
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 201.21907205462696
# ###################
# Bin number 2
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.5478868472543
# ###################
# Bin number 3
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 213.27326974415547
# ###################
# Bin number 4
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 210.94632410455839
# ###################
# Bin number 5
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.4735148131526
# ###################
# Bin number 6
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 214.00111238706015
# ###################
# Bin number 7
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 215.88431808249453
# ###################
# Bin number 8
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 217.4795440802005
# ###################
# Bin number 9
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 217.05450309664567
# ###################
# Bin number 10
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 211.87182649139788
# ###################
# Bin number 11
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 218.56842828234028
# ###################
# Bin number 12
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 213.46946394519568
# ###################
# Bin number 13
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 215.3566615085506
# ###################
# Bin number 14
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.32382158554196
# ###################
# Bin number 15
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 217.28186590704462
# ###################
# Bin number 16
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.82214991122135
# ###################
# Bin number 17
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.72352329259004
# ###################
# Bin number 18
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 201.06097493603272
# ###################
# Bin number 19
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.53623460641825
# ###################
# Bin number 20
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 196.93746936168958
# ###################
# Bin number 21
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.1635419351959
# ###################
# Bin number 22
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.11240221716233
# ###################
# Bin number 23
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 236.30167982933634
# ###################
# Bin number 24
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.09298883027319
# ###################
# Bin number 25
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 231.3511367613414
# ###################
# Bin number 26
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.25258078551494
# ###################
# Bin number 27
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.39095229559223
# ###################
# Bin number 28
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 224.95645372859886
# ###################
# Bin number 29
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.55943830451537
# ###################
# Bin number 30
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 201.67904407201095
# ###################
# Bin number 31
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 188.6558249378495
# ###################
# Bin number 32
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.88815727271484
# ###################
# Bin number 33
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 168.4878461022923
# ###################
# Bin number 34
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 224.0472774362686
# ###################
# Bin number 35
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 208.83209180313227
# ###################
# Bin number 36
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.1635419351959
# ###################
# Bin number 37
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 196.11531979726428
# ###################
# Bin number 38
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 167.3130254399405
# ###################
# Bin number 39
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 177.98417600211366
# ###################
# Bin number 40
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 163.9399897775346
# ###################
# Bin number 41
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 173.80869050903294
# ###################
# Bin number 42
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 172.72693957686656
# ###################
# Bin number 43
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.53623460641825
# ###################
# Bin number 44
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.32397795523957
# ###################
# Bin number 45
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.76629656062426
# ###################
# Bin number 46
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.32397795523957
# ###################
# Bin number 47
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 164.28831904815922
# ###################
# Bin number 48
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.97471075175827
# ###################
# Bin number 49
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 171.3576681855198
# ###################
# Bin number 50
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 142.9546185937718
# ###################
# Bin number 51
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.24138080158522
# ###################
# Bin number 52
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 175.00276234751604
# ###################
# Bin number 53
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 168.8264605593911
# ###################
# Bin number 54
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 209.0831837669886
# ###################
# Bin number 55
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.79963965397945
# ###################
# Bin number 56
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 179.34557263642648
# ###################
# Bin number 57
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.5251816753253
# ###################
# Bin number 58
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.37649588833864
# ###################
# Bin number 59
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.9059093017826
# ###################
# Bin number 60
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 183.69398666816426
# ###################
# Bin number 61
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.61501590210833
# ###################
# Bin number 62
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Check this fit...
# 138.6579736301094
# ###################
# Bin number 63
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 138.3330247734706
# ###################
# Bin number 64
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 183.66756592545377
# ###################
# Bin number 65
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.16675429666284
# ###################
# Bin number 66
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.37649588833864
# ###################
# Bin number 67
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.95059814489625
# ###################
# Bin number 68
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 171.71002250295987
# ###################
# Bin number 69
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.9059093017826
# ###################
# Bin number 70
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 195.9195823142337
# ###################
# Bin number 71
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 148.58686431395748
# ###################
# Bin number 72
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.05021967624597
# ###################
# Bin number 73
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.95059814489625
# ###################
# Bin number 74
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.7864930832077
# ###################
# Bin number 75
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 165.64462136530122
# ###################
# Bin number 76
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 200.5078356810101
# ###################
# Bin number 77
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 187.92475102438232
# ###################
# Bin number 78
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.7864930832077
# ###################
# Bin number 79
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 217.41299115393693
# ###################
# Bin number 80
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.862689723424
# ###################
# Bin number 81
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 156.93059877710567
# ###################
# Bin number 82
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 195.6163033253957
# ###################
# Bin number 83
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 209.88164580832205
# ###################
# Bin number 84
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 218.98347662378424
# ###################
# Bin number 85
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.862689723424
# ###################
# Bin number 86
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.37731526669103
# ###################
# Bin number 87
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 213.70673766789076
# ###################
# Bin number 88
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 231.23608232283118
# ###################
# Bin number 89
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 231.54823690650866
# ###################
# Bin number 90
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 227.51806799677658
# ###################
# Bin number 91
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 221.93548667955923
# ###################
# Bin number 92
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 233.41375218265821
# ###################
# Bin number 93
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.41345989420162
# ###################
# Bin number 94
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 233.41375218265821
# ###################
# Bin number 95
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 215.90122325190023
# ###################
# Bin number 96
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 221.58714312396657
# ###################
# Bin number 97
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.57277531774093
# ###################
# Bin number 98
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 221.93548667955923
# ###################
# Bin number 99
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 191.2882626358346
# ###################
# Bin number 100
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.48905959292145
# ###################
# Bin number 101
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 219.55410395804722
# ###################
# Bin number 102
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 158.17952759066117
# ###################
# Bin number 103
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.88885927424494
# ###################
# Bin number 104
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 229.5721043755378
# ###################
# Bin number 105
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.84780600611828
# ###################
# Bin number 106
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 227.68373317428222
# ###################
# Bin number 107
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.46250251327638
# ###################
# Bin number 108
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.54768955710222
# ###################
# Bin number 109
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.25927811577014
# ###################
# Bin number 110
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.36981754009815
# ###################
# Bin number 111
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 220.34594140899364
# ###################
# Bin number 112
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.89790101263785
# ###################
# Bin number 113
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.46250251327638
# ###################
# Bin number 114
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 214.377054392161
# ###################
# Bin number 115
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.00963943664973
# ###################
# Bin number 116
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 214.6881809092971
# ###################
# Bin number 117
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.0942339413303
# ###################
# Bin number 118
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.66435691478304
# ###################
# Bin number 119
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.6332870690702
# ###################
# Bin number 120
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 200.7279012908458
# ###################
# Bin number 121
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 211.0567925910777
# ###################
# Bin number 122
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.59493619263043
# ###################
# Bin number 123
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.62474523926244
# ###################
# Bin number 124
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 226.76461408488427
# ###################
# Bin number 125
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.28174160935737
# ###################
# Bin number 126
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 233.76916095736297
# ###################
# Bin number 127
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.66435691478304
# ###################
# Bin number 128
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.1971570185688
# ###################
# Bin number 129
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 158.58387968745959
# ###################
# Bin number 130
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.9173927504188
# ###################
# Bin number 131
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.00102626295984
# ###################
# Bin number 132
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 229.0828788567824
# ###################
# Bin number 133
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 191.81333204513444
# ###################
# Bin number 134
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.0672394241153
# ###################
# Bin number 135
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 196.98168754426587
# ###################
# Bin number 136
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 190.02013989707524
# ###################
# Bin number 137
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 189.94814387826509
# ###################
# Bin number 138
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 181.44448456556512
# ###################
# Bin number 139
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 201.7297642622263
# ###################
# Bin number 140
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.00102626295984
# ###################
# Bin number 141
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 169.12613057152242
# ###################
# Bin number 142
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 181.4388244703555
# ###################
# Bin number 143
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 155.05364439005254
# ###################
# Bin number 144
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 210.56877165273445
# ###################
# Bin number 145
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 211.1873991182426
# ###################
# Bin number 146
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 186.90076695601454
# ###################
# Bin number 147
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.60226391982695
# ###################
# Bin number 148
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 179.1185100448316
# ###################
# Bin number 149
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 178.30540826334803
# ###################
# Bin number 150
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.97810538735814
# ###################
# Bin number 151
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 179.1185100448316
# ###################
# Bin number 152
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.993504338847
# ###################
# Bin number 153
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.46159420189966
# ###################
# Bin number 154
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 171.57468113344268
# ###################
# Bin number 155
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 189.39198908852947
# ###################
# Bin number 156
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 171.45846073389922
# ###################
# Bin number 157
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.60066318898487
# ###################
# Bin number 158
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 127.69813261578872
# ###################
# Bin number 159
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 170.27812640098205
# ###################
# Bin number 160
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 194.88511789215792
# ###################
# Bin number 161
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 165.32850688903795
# ###################
# Bin number 162
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.86452282987938
# ###################
# Bin number 163
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 193.38811824706758
# ###################
# Bin number 164
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Check this fit...
# 203.96214520106702
# ###################
# Bin number 165
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 209.5363289395765
# ###################
# Bin number 166
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.64395983488092
# ###################
# Bin number 167
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 200.01946192397017
# ###################
# Bin number 168
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 214.1870943785149
# ###################
# Bin number 169
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 189.5856310637015
# ###################
# Bin number 170
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 231.94585165235648
# ###################
# Bin number 171
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 214.1764116778107
# ###################
# Bin number 172
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.31012560804817
# ###################
# Bin number 173
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.8452129868158
# ###################
# Bin number 174
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 226.40397140488997
# ###################
# Bin number 175
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 160.50471058183186
# ###################
# Bin number 176
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 188.39598015669227
# ###################
# Bin number 177
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 210.0291843732834
# ###################
# Bin number 178
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 192.25574230848827
# ###################
# Bin number 179
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 203.1036544411573
# ###################
# Bin number 180
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 161.14110759002142
# ###################
# Bin number 181
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 133.41080364259304
# ###################
# Bin number 182
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 220.0199147745933
# ###################
# Bin number 183
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 226.66265868418256
# ###################
# Bin number 184
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.74296103046274
# ###################
# Bin number 185
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 165.05436176461032
# ###################
# Bin number 186
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 142.94600406491435
# ###################
# Bin number 187
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 150.7394318752951
# ###################
# Bin number 188
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 183.94019199414632
# ###################
# Bin number 189
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 129.72055713227695
# Approximating closest positive semi-definite covariance matrix
# Approximating again with lower threshold
# Colorbar... vmin and vmax  -190.70596527480095 977.1210158025617
# Colorbar... vmin and vmax  -190.70596527480095 325.5021945245933
#
# ####################################
#
# VD finished.
#
# Calculating Vs and sigmas
#
#
# ###################
# Bin number 0
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# -1.2919463131063083
# ###################
# Bin number 1
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 2.0798099967078527
# ###################
# Bin number 2
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1.2717746385534443
# ###################
# Bin number 3
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# -5.196009425543006
# ###################
# Bin number 4
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 3.9070948545145967
# ###################
# Bin number 5
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 5.228803240378105
# ###################
# Bin number 6
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 0.3511824471170484
# ###################
# Bin number 7
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 2.934071220985586
# ###################
# Bin number 8
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# -9.033941252447438
# ###################
# Bin number 9
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# -0.023184512600001723
# ###################
# Bin number 10
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 3.1964208023388476
# ###################
# Bin number 11
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# -6.410198082837591
# ###################
# Bin number 12
# ...
#   category=OptimizeWarning)
# 192.04463808532626
# ###################
# Bin number 32
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 205.4345222112838
# ###################
# Bin number 33
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.42647489475635
# ###################
# Bin number 34
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.00471312068413
# ###################
# Bin number 35
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 151.4810880089101
# ###################
# Bin number 36
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 179.8052161588187
# ###################
# Bin number 37
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 199.62524212006542
# ###################
# Bin number 38
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 226.57619937488042
# ###################
# Bin number 39
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 213.11245672089228
# ###################
# Bin number 40
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 211.35137047637636
# ###################
# Bin number 41
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 200.4667134027068
# ###################
# Bin number 42
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.92292829365027
# ###################
# Bin number 43
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 220.34320159759793
# ###################
# Bin number 44
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 208.00650656541248
# ###################
# Bin number 45
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 210.69484248759926
# ###################
# Bin number 46
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 216.96974713680453
# ###################
# Bin number 47
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 209.8864037216313
# ###################
# Bin number 48
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 221.95715602719034
# ###################
# Bin number 49
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 178.8447300922679
# ###################
# Bin number 50
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.49005002001215
# ###################
# Bin number 51
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.2578388474775
# ###################
# Bin number 52
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.44876764758496
# ###################
# Bin number 53
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 223.59674646233103
# ###################
# Bin number 54
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 227.5301286482147
# ###################
# Bin number 55
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.13933373945576
# ###################
# Bin number 56
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.51220047666024
# ###################
# Bin number 57
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 231.34193262339917
# ###################
# Bin number 58
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 217.2756747907903
# ###################
# Bin number 59
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 232.32089834561407
# ###################
# Bin number 60
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 138.54780936368738
# ###################
# Bin number 61
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 221.96834576895134
# ###################
# Bin number 62
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 192.17383191790142
# ###################
# Bin number 63
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 224.3472337685431
# ###################
# Bin number 64
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225.81630650484783
# ###################
# Bin number 65
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.5795241902209
# ###################
# Bin number 66
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 227.98316919805393
# ###################
# Bin number 67
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 227.98928394534911
# ###################
# Bin number 68
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 168.93289928175514
# ###################
# Bin number 69
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.35303544425264
# ###################
# Bin number 70
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.0752469966628
# ###################
# Bin number 71
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.21177186160705
# ###################
# Bin number 72
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.72363630356892
# ###################
# Bin number 73
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.773444510559
# ###################
# Bin number 74
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 198.38130221417742
# ###################
# Bin number 75
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 202.76723243792802
# ###################
# Bin number 76
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 201.4572337313908
# ###################
# Bin number 77
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 185.58967401274356
# ###################
# Bin number 78
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 181.85156466106915
# ###################
# Bin number 79
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 174.35279147932903
# ###################
# Bin number 80
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 195.17414743586272
# ###################
# Bin number 81
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 212.09951632722994
# ###################
# Bin number 82
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 208.79554962725035
# ###################
# Bin number 83
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 191.16511404574314
# ###################
# Bin number 84
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 207.2517312252816
# ###################
# Bin number 85
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 206.64198574292752
# ###################
# Bin number 86
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 194.97868880606146
# ###################
# Bin number 87
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 208.16472067822303
# ###################
# Bin number 88
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 197.1938382752733
# ###################
# Bin number 89
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 174.7163884111777
# ###################
# Bin number 90
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 204.88811760702248
# ###################
# Bin number 91
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 200.8523820433053
# ###################
# Bin number 92
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 171.728416876579
# ###################
# Bin number 93
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 150.8532294789132
# ###################
# Bin number 94
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 185.36496465396854
# ###################
# Bin number 95
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 152.26911005512488
# ###################
# Bin number 96
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 185.31490368886617
# Approximating closest positive semi-definite covariance matrix
# Approximating again with lower threshold
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-1f7ed17a9bda> in <module>()
#     163                     covariance_matrix = cov_nearest(covariance_matrix, threshold=1e-13)
#     164                     cov_matrix_header = 'This covariance matrix has been smoothed to the closest positive semi-definite covariance matrix'
# --> 165                 assert(is_pos_semidef(covariance_matrix)) , "covariance matrix still not positive semi-definite, take a closer look"
#     166                 # save covariance matrix
#     167                 np.savetxt(f'{fin_g_dir}{obj_name}_covariance_matrix_{vel_moment}.txt', covariance_matrix,
#
# AssertionError: covariance matrix still not positive semi-definite, take a closer look
